# %% [markdown]
# ## Setup

# %%
import pandas as pd
import requests
import json
import math
import os
from dotenv import load_dotenv

load_dotenv()

NOTION_SECRET = os.getenv("NOTION_SECRET")
DATABASE_ID = os.getenv("DATABASE_ID")

# %% [markdown]
# ## Get data from google

# %%
def google_book_search(title, author, publisher):
    search_terms = " ".join(filter(None, [title, author, publisher]))
    url = 'https://www.googleapis.com/books/v1/volumes?q='
    response = requests.get(url+search_terms)
    data = response.json()
    # Normalizing data
    df = pd.json_normalize(data, record_path=['items'])
    return df


search_terms = "maniac labatut"
url = 'https://www.googleapis.com/books/v1/volumes?q='
response = requests.get(url+search_terms)
data = response.json()
# # Normalizing data
df = pd.json_normalize(data, record_path=['items'])

# %%
def query_databases(secret_key, database_id):
    url = "https://api.notion.com/v1/databases/"+database_id+'/query'

    payload = {'id': database_id}
    headers = {
        'Notion-Version': '2021-05-13',
        'Authorization': 'Bearer '+secret_key
    }

    response = requests.request(
        "POST", url, headers=headers, data=payload)
    print(f"The response code is {response.status_code}")
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    else:
        return response.json()

# %%
res = query_databases(NOTION_SECRET, DATABASE_ID)
# Out:
# The response code is 200

# %%
res.get('results')[0].get('properties')[
    'Summary']['rich_text'][0].get('plain_text')
# Out:
# 'Dieses eBook: "Moby Dick" ist mit einem detaillierten und dynamischen Inhaltsverzeichnis versehen und wurde sorgfältig korrekturgelesen. Moby-Dick beginnt mit dem Satz: "Call me Ishmael." Es folgt die Ich-Erzählung des Matrosen Ismael (sein voller Name wird nie genannt), der aus einer angesehenen Familie stammt und sich entscheidet, als Matrose zur See zu fahren, um seiner Melancholie zu entfliehen. Er spricht von einem unbändigen Drang in ihm, der ihn überkomme, wenn er des Festlands überdrüssig sei. Ismael hat bereits einige Fahrten auf Handelsschiffen hinter sich, will nun aber auf einem Walfänger anheuern. Das erzählerische Rückgrat des Romans ist die schicksalhafte Fahrt des Walfangschiffes Pequod, dessen einbeiniger Kapitän Ahab mit blindem Hass den weißen Pottwal jagt, der ihm das Bein abgerissen hat. Entlang dieses erzählerischen Fadens reiht Melville zahlreiche philosophische, wissenschaftliche, kunstgeschichtliche und mythologische Exkurse. Dieses eBook ist eine Überarbeitung von Wilhelm Strüvers Übersetzung der Erstausgabe von 1927/28, wie sie von Thomas Mann herausgegeben wurde.'

# %%
notion_columns = ['Category', 'Publisher', 'Summary', 'Current page', 'Link',
                  'Total pages', 'Date started', 'Author', 'Title', 'url', 'page_id']
notion = pd.DataFrame(columns=notion_columns)
print(notion.columns)
print(notion.head())
for page in res.get('results'):
    properties = page.get('properties')
    try:
        author = properties.get('Author').get('rich_text')[0].get('plain_text')
    except IndexError:
        author = None
    try:
        title = properties.get('Title').get('title')[0].get('plain_text')
    except IndexError:
        title = None
    try:
        publisher = properties['Publisher']['select']['name']
    except KeyError:
        publisher = None
    try:
        category = properties['Category']['select']['name']
    except KeyError:
        category = None
    try:
        summary = properties['Summary']['rich_text'][0]['plain_text']
    except IndexError:
        summary = None
    try:
        current_page = properties['Current page']['number']
    except KeyError:
        current_page = None
    try:
        link = properties['Link']['url']
    except KeyError:
        link = None
    total_pages = properties['Total pages']['number']
    try:
        date_started = properties['Date started']['date']['start']
    except KeyError:
        date_started = None

    url = page.get('url')
    page_id = url[-32:]
    # concat the data
    notion = pd.concat([notion, pd.DataFrame([[category, publisher, summary, current_page, link, total_pages,
                       date_started, author, title, url, page_id]], columns=notion_columns)], ignore_index=True)
# drop rows without title
notion = notion.dropna(subset=['Title'])
# Out:
# Index(['Category', 'Publisher', 'Summary', 'Current page', 'Link',
#        'Total pages', 'Date started', 'Author', 'Title', 'url', 'page_id'],
#       dtype='object')
# Empty DataFrame
# Columns: [Category, Publisher, Summary, Current page, Link, Total pages, Date started, Author, Title, url, page_id]
# Index: []

# %%
google_results = pd.DataFrame()

for book in notion.itertuples():

    google_results = pd.concat([google_results, google_book_search(
        book.Title, book.Author, book.Publisher)], ignore_index=True)

# %%
google_data = google_results[['selfLink', 'volumeInfo.title',
                              'volumeInfo.subtitle', 'volumeInfo.authors', 'volumeInfo.publisher',
                              'volumeInfo.publishedDate', 'volumeInfo.description', 'volumeInfo.pageCount', 'volumeInfo.categories',
                              'volumeInfo.imageLinks.smallThumbnail', 'volumeInfo.imageLinks.thumbnail', 'saleInfo.country', 'saleInfo.retailPrice.amount',
                              'saleInfo.retailPrice.currencyCode'
                              ]]

# %%
import pandas as pd


def clean_google_data(google_df, notion_df):
    filtered_results = []

    for _, notion_row in notion_df.iterrows():
        try:
            # Convert Notion title to lowercase and split into words
            notion_title_words = notion_row['Title'].lower().split()
            # Create a regex pattern to match all words
            pattern = '.*'.join(notion_title_words)
            # Filter google_df by title using regex
            matches = google_df[google_df['volumeInfo.title'].str.lower(
            ).str.contains(pattern, regex=True, na=False)]
            # add page_id to matches as column
            matches['page_id'] = notion_row['page_id']

        except TypeError as e:
            print(f"TypeError encountered while filtering by title: {e}")
            continue

        try:
            # Further filter by author if available
            if pd.notna(notion_row.get('Author')):
                tmp_df = matches[matches['volumeInfo.authors'].apply(
                    lambda authors: notion_row['Author'] in authors if isinstance(authors, list) else False)]
                if not tmp_df.empty:  # If there are matches, keep them
                    matches = tmp_df
        except TypeError as e:
            print(f"TypeError encountered while filtering by author: {e}")
            continue

        try:
            # Further filter by publisher if available
            if pd.notna(notion_row.get('Publisher')):
                tmp_df = matches[matches['volumeInfo.publisher'].apply(
                    lambda publisher: notion_row['Publisher'] == publisher if isinstance(publisher, str) else False)]
                if not tmp_df.empty:  # If there are matches, keep them
                    matches = tmp_df

        except TypeError as e:
            print(f"TypeError encountered while filtering by publisher: {e}")
            continue
        try:
            # If there are matches, keep the latest by published_date
            latest_match = matches.sort_values(
                by='volumeInfo.publishedDate', ascending=False).iloc[0]
            filtered_results.append(latest_match)
        except IndexError as e:
            # only single match, append
            if not matches.empty:
                filtered_results.append(matches)
            else:
                print(f"No match found for {notion_row['Title']}")
            continue
        except KeyError:
            if not matches.empty:
                filtered_results.append(matches)
            else:
                print(f"No match found for {notion_row['Title']}")
            continue

    # Convert the list of filtered results to a DataFrame
    filtered_df = pd.DataFrame(filtered_results)
    return filtered_df

# %%
clean_google_data = clean_google_data(google_data, notion)
clean_google_data
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
# C:\Users\chris\AppData\Local\Temp\ipykernel_260856\1456673457.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['page_id'] = notion_row['page_id']
#                                               selfLink  \
# 9    https://www.googleapis.com/books/v1/volumes/Xq...
# 10   https://www.googleapis.com/books/v1/volumes/ui...
# 29   https://www.googleapis.com/books/v1/volumes/yS...
# 30   https://www.googleapis.com/books/v1/volumes/nG...
# 44   https://www.googleapis.com/books/v1/volumes/ng...
# ..                                                 ...
# 670  https://www.googleapis.com/books/v1/volumes/im...
# 686  https://www.googleapis.com/books/v1/volumes/9j...
# 690  https://www.googleapis.com/books/v1/volumes/kT...
# 701  https://www.googleapis.com/books/v1/volumes/yP...
# 714  https://www.googleapis.com/books/v1/volumes/On...
#
#                          volumeInfo.title  \
# 9            Moby Dick by Herman Melville
# 10                           Winterbienen
# 29                     Mythos Illustrated
# 30                          Über Menschen
# 44   Altes Land - Mittagsstunde - Zur See
# ..                                    ...
# 670                            Astronomie
# 686                           Vida de Ali
# 690                           Anaximander
# 701            Annette, ein Heldinnenepos
# 714                             22 Bahnen
#
#                                    volumeInfo.subtitle    volumeInfo.authors  \
# 9                                                  NaN     [Herman Melville]
# 10                                               Roman     [Norbert Scheuer]
# 29                                                 NaN         [Stephen Fry]
# 30                                               Roman            [Juli Zeh]
# 44   Alle Hörbuch-Bestseller von Dörte Hansen in ei...        [Dörte Hansen]
# ..                                                 ...                   ...
# 670                          die kosmische Perspektive  [Jeffrey O. Bennett]
# 686                                                NaN        [Jonathan Eig]
# 690                          And the Nature of Science       [Carlo Rovelli]
# 701                                     von Anne Weber    [Sonja Szillinsky]
# 714                                            Lektüre       [Caroline Wahl]
#
#             volumeInfo.publisher volumeInfo.publishedDate  \
# 9                            NaN               2020-12-30
# 10                      C.H.Beck               2019-07-18
# 29                  Random House               2023-10-19
# 30   Luchterhand Literaturverlag               2021-03-22
# 44                           NaN                     2023
# ..                           ...                      ...
# 670     Pearson Deutschland GmbH                     2010
# 686         Capitán Swing Libros               2022-11-14
# 690                 Random House               2023-02-23
# 701                          NaN                     2022
# 714                          NaN                  2024-10
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 9    One of the greatest books ever written. A sple...                 242.0
# 10   Januar 1944: Während über der Eifel britische ...                 250.0
# 29   Pre-order Mythos Illustrated. No one loves and...                 399.0
# 30   Dora ist mit ihrer kleinen Hündin aufs Land ge...                 351.0
# 44                                                 NaN                   0.0
# ..                                                 ...                   ...
# 670                                                NaN                1228.0
# 686  La biografía más completa y definitiva de Muha...                 887.0
# 690  'Anaximander is a delight and so is this book'...                 195.0
# 701                                                NaN                   0.0
# 714                                                NaN                   0.0
#
#            volumeInfo.categories  \
# 9                            NaN
# 10                     [Fiction]
# 29     [Comics & Graphic Novels]
# 30                     [Fiction]
# 44                           NaN
# ..                           ...
# 670                  [Astronomy]
# 686  [Biography & Autobiography]
# 690                    [Science]
# 701                          NaN
# 714                          NaN
#
#                   volumeInfo.imageLinks.smallThumbnail  \
# 9    http://books.google.com/books/content?id=Xq4hz...
# 10   http://books.google.com/books/content?id=uiiVD...
# 29   http://books.google.com/books/content?id=ySa-E...
# 30   http://books.google.com/books/content?id=nGIGE...
# 44                                                 NaN
# ..                                                 ...
# 670  http://books.google.com/books/content?id=im_SY...
# 686  http://books.google.com/books/content?id=9j2dE...
# 690  http://books.google.com/books/content?id=kTpwE...
# 701                                                NaN
# 714                                                NaN
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 9    http://books.google.com/books/content?id=Xq4hz...               DE
# 10   http://books.google.com/books/content?id=uiiVD...               DE
# 29   http://books.google.com/books/content?id=ySa-E...               DE
# 30   http://books.google.com/books/content?id=nGIGE...               DE
# 44                                                 NaN               DE
# ..                                                 ...              ...
# 670  http://books.google.com/books/content?id=im_SY...               DE
# 686  http://books.google.com/books/content?id=9j2dE...               DE
# 690  http://books.google.com/books/content?id=kTpwE...               DE
# 701                                                NaN               DE
# 714                                                NaN               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode  \
# 9                            NaN                               NaN
# 10                          9.49                               EUR
# 29                         18.99                               EUR
# 30                         10.99                               EUR
# 44                           NaN                               NaN
# ..                           ...                               ...
# 670                          NaN                               NaN
# 686                        12.99                               EUR
# 690                        14.99                               EUR
# 701                          NaN                               NaN
# 714                          NaN                               NaN
#
#                               page_id
# 9    8ae970fcc5034b6ca551eee7e434b2b4
# 10   36a8bcd366d64786b768eb2509ff3e6f
# 29   eb60075d9db74e36ba530479bb452c36
# 30   a044186a86014c3b89fb198155814ada
# 44   b30e1dd1d3c64ce48d768bde69d3c2a8
# ..                                ...
# 670  8a838eaa595d45d8bb1899b2246324c6
# 686  f9338061df794fd3b9086bad63615b78
# 690  3f8a812a9b9a40afac54d856189e7d7c
# 701  fcfb16d9e44e48768fc04d1f995ffd3a
# 714  7cf9cf2022604b6a96e4294a83faf7d7
#
# [72 rows x 15 columns]

# %%
clean_google_data
# Out:
#                                               selfLink  \
# 9    https://www.googleapis.com/books/v1/volumes/Xq...
# 10   https://www.googleapis.com/books/v1/volumes/ui...
# 29   https://www.googleapis.com/books/v1/volumes/yS...
# 30   https://www.googleapis.com/books/v1/volumes/nG...
# 44   https://www.googleapis.com/books/v1/volumes/ng...
# ..                                                 ...
# 670  https://www.googleapis.com/books/v1/volumes/im...
# 686  https://www.googleapis.com/books/v1/volumes/9j...
# 690  https://www.googleapis.com/books/v1/volumes/kT...
# 701  https://www.googleapis.com/books/v1/volumes/yP...
# 714  https://www.googleapis.com/books/v1/volumes/On...
#
#                          volumeInfo.title  \
# 9            Moby Dick by Herman Melville
# 10                           Winterbienen
# 29                     Mythos Illustrated
# 30                          Über Menschen
# 44   Altes Land - Mittagsstunde - Zur See
# ..                                    ...
# 670                            Astronomie
# 686                           Vida de Ali
# 690                           Anaximander
# 701            Annette, ein Heldinnenepos
# 714                             22 Bahnen
#
#                                    volumeInfo.subtitle    volumeInfo.authors  \
# 9                                                  NaN     [Herman Melville]
# 10                                               Roman     [Norbert Scheuer]
# 29                                                 NaN         [Stephen Fry]
# 30                                               Roman            [Juli Zeh]
# 44   Alle Hörbuch-Bestseller von Dörte Hansen in ei...        [Dörte Hansen]
# ..                                                 ...                   ...
# 670                          die kosmische Perspektive  [Jeffrey O. Bennett]
# 686                                                NaN        [Jonathan Eig]
# 690                          And the Nature of Science       [Carlo Rovelli]
# 701                                     von Anne Weber    [Sonja Szillinsky]
# 714                                            Lektüre       [Caroline Wahl]
#
#             volumeInfo.publisher volumeInfo.publishedDate  \
# 9                            NaN               2020-12-30
# 10                      C.H.Beck               2019-07-18
# 29                  Random House               2023-10-19
# 30   Luchterhand Literaturverlag               2021-03-22
# 44                           NaN                     2023
# ..                           ...                      ...
# 670     Pearson Deutschland GmbH                     2010
# 686         Capitán Swing Libros               2022-11-14
# 690                 Random House               2023-02-23
# 701                          NaN                     2022
# 714                          NaN                  2024-10
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 9    One of the greatest books ever written. A sple...                 242.0
# 10   Januar 1944: Während über der Eifel britische ...                 250.0
# 29   Pre-order Mythos Illustrated. No one loves and...                 399.0
# 30   Dora ist mit ihrer kleinen Hündin aufs Land ge...                 351.0
# 44                                                 NaN                   0.0
# ..                                                 ...                   ...
# 670                                                NaN                1228.0
# 686  La biografía más completa y definitiva de Muha...                 887.0
# 690  'Anaximander is a delight and so is this book'...                 195.0
# 701                                                NaN                   0.0
# 714                                                NaN                   0.0
#
#            volumeInfo.categories  \
# 9                            NaN
# 10                     [Fiction]
# 29     [Comics & Graphic Novels]
# 30                     [Fiction]
# 44                           NaN
# ..                           ...
# 670                  [Astronomy]
# 686  [Biography & Autobiography]
# 690                    [Science]
# 701                          NaN
# 714                          NaN
#
#                   volumeInfo.imageLinks.smallThumbnail  \
# 9    http://books.google.com/books/content?id=Xq4hz...
# 10   http://books.google.com/books/content?id=uiiVD...
# 29   http://books.google.com/books/content?id=ySa-E...
# 30   http://books.google.com/books/content?id=nGIGE...
# 44                                                 NaN
# ..                                                 ...
# 670  http://books.google.com/books/content?id=im_SY...
# 686  http://books.google.com/books/content?id=9j2dE...
# 690  http://books.google.com/books/content?id=kTpwE...
# 701                                                NaN
# 714                                                NaN
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 9    http://books.google.com/books/content?id=Xq4hz...               DE
# 10   http://books.google.com/books/content?id=uiiVD...               DE
# 29   http://books.google.com/books/content?id=ySa-E...               DE
# 30   http://books.google.com/books/content?id=nGIGE...               DE
# 44                                                 NaN               DE
# ..                                                 ...              ...
# 670  http://books.google.com/books/content?id=im_SY...               DE
# 686  http://books.google.com/books/content?id=9j2dE...               DE
# 690  http://books.google.com/books/content?id=kTpwE...               DE
# 701                                                NaN               DE
# 714                                                NaN               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode  \
# 9                            NaN                               NaN
# 10                          9.49                               EUR
# 29                         18.99                               EUR
# 30                         10.99                               EUR
# 44                           NaN                               NaN
# ..                           ...                               ...
# 670                          NaN                               NaN
# 686                        12.99                               EUR
# 690                        14.99                               EUR
# 701                          NaN                               NaN
# 714                          NaN                               NaN
#
#                               page_id
# 9    8ae970fcc5034b6ca551eee7e434b2b4
# 10   36a8bcd366d64786b768eb2509ff3e6f
# 29   eb60075d9db74e36ba530479bb452c36
# 30   a044186a86014c3b89fb198155814ada
# 44   b30e1dd1d3c64ce48d768bde69d3c2a8
# ..                                ...
# 670  8a838eaa595d45d8bb1899b2246324c6
# 686  f9338061df794fd3b9086bad63615b78
# 690  3f8a812a9b9a40afac54d856189e7d7c
# 701  fcfb16d9e44e48768fc04d1f995ffd3a
# 714  7cf9cf2022604b6a96e4294a83faf7d7
#
# [72 rows x 15 columns]

# %%
# merge clean google and notion data on page_id
complete = pd.merge(notion, clean_google_data, on='page_id', how='left')
complete
# Out:
#    Category  Publisher                                            Summary  \
# 0   Fiction        dtv  Dieses eBook: "Moby Dick" ist mit einem detail...
# 1   Fiction  C.H. Beck  Januar 1944: Während über der Eifel britische ...
# 2      None       None  Was ist Mythos? Der Autor charakterisiert den ...
# 3      None       None  Dora ist mit ihrer kleinen Hündin aufs Land ge...
# 4      None       None                                               None
# ..      ...        ...                                                ...
# 67     None       None  Die Astronomie untersucht die Eigenschaften de...
# 68     None       None  Ein liniertes Notizbuch in Standartgröße. Auf ...
# 69     None       None  The edition of the works of the three sixth-ce...
# 70  Fiction       None  Mit dem Deutschen Buchpreis 2020 ausgezeichnet...
# 71     None       None  Tildas Tage sind strikt durchgetaktet: studier...
#
#    Current page                                               Link  \
# 0            20  https://www.googleapis.com/books/v1/volumes/Vq...
# 1           250  https://www.googleapis.com/books/v1/volumes/ui...
# 2          None  https://www.googleapis.com/books/v1/volumes/BY...
# 3          None  https://www.googleapis.com/books/v1/volumes/nG...
# 4          None  https://www.googleapis.com/books/v1/volumes/PK...
# ..          ...                                                ...
# 67         None  https://www.googleapis.com/books/v1/volumes/lq...
# 68         None  https://www.googleapis.com/books/v1/volumes/tO...
# 69         None  https://www.googleapis.com/books/v1/volumes/rR...
# 70         None  https://www.googleapis.com/books/v1/volumes/1n...
# 71         None  https://www.googleapis.com/books/v1/volumes/dN...
#
#    Total pages Date started              Author                       Title  \
# 0          920   2024-08-11     Herman Melville                   Moby Dick
# 1          250   2021-02-28     Norbert Scheuer                Winterbienen
# 2          468   2023-11-14         Stephen Fry                      Mythos
# 3          320   2021-04-01            Juli Zeh               Über Menschen
# 4          208   2022-12-10        Dörte Hansen                     Zur See
# ..         ...          ...                 ...                         ...
# 67        1228   2024-03-22  Jeffrey O. Bennett                  Astronomie
# 68         661         None        Jonathan Eig                         Ali
# 69         195   2023-02-24       Carlo Rovelli                 Anaximander
# 70         201   2023-06-11       Annette Weber  Annette, ein Heldinnenepos
# 71         203   2024-03-23       Caroline Wahl                   22 Bahnen
#
#                                                   url  ...  \
# 0   https://www.notion.so/Moby-Dick-8ae970fcc5034b...  ...
# 1   https://www.notion.so/Winterbienen-36a8bcd366d...  ...
# 2   https://www.notion.so/Mythos-eb60075d9db74e36b...  ...
# 3   https://www.notion.so/ber-Menschen-a044186a860...  ...
# 4   https://www.notion.so/Zur-See-b30e1dd1d3c64ce4...  ...
# ..                                                ...  ...
# 67  https://www.notion.so/Astronomie-8a838eaa595d4...  ...
# 68  https://www.notion.so/Ali-f9338061df794fd3b908...  ...
# 69  https://www.notion.so/Anaximander-3f8a812a9b9a...  ...
# 70  https://www.notion.so/Annette-ein-Heldinnenepo...  ...
# 71  https://www.notion.so/22-Bahnen-7cf9cf2022604b...  ...
#
#            volumeInfo.publisher volumeInfo.publishedDate  \
# 0                           NaN               2020-12-30
# 1                      C.H.Beck               2019-07-18
# 2                  Random House               2023-10-19
# 3   Luchterhand Literaturverlag               2021-03-22
# 4                           NaN                     2023
# ..                          ...                      ...
# 67     Pearson Deutschland GmbH                     2010
# 68         Capitán Swing Libros               2022-11-14
# 69                 Random House               2023-02-23
# 70                          NaN                     2022
# 71                          NaN                  2024-10
#
#                                volumeInfo.description volumeInfo.pageCount  \
# 0   One of the greatest books ever written. A sple...                242.0
# 1   Januar 1944: Während über der Eifel britische ...                250.0
# 2   Pre-order Mythos Illustrated. No one loves and...                399.0
# 3   Dora ist mit ihrer kleinen Hündin aufs Land ge...                351.0
# 4                                                 NaN                  0.0
# ..                                                ...                  ...
# 67                                                NaN               1228.0
# 68  La biografía más completa y definitiva de Muha...                887.0
# 69  'Anaximander is a delight and so is this book'...                195.0
# 70                                                NaN                  0.0
# 71                                                NaN                  0.0
#
#           volumeInfo.categories  \
# 0                           NaN
# 1                     [Fiction]
# 2     [Comics & Graphic Novels]
# 3                     [Fiction]
# 4                           NaN
# ..                          ...
# 67                  [Astronomy]
# 68  [Biography & Autobiography]
# 69                    [Science]
# 70                          NaN
# 71                          NaN
#
#                  volumeInfo.imageLinks.smallThumbnail  \
# 0   http://books.google.com/books/content?id=Xq4hz...
# 1   http://books.google.com/books/content?id=uiiVD...
# 2   http://books.google.com/books/content?id=ySa-E...
# 3   http://books.google.com/books/content?id=nGIGE...
# 4                                                 NaN
# ..                                                ...
# 67  http://books.google.com/books/content?id=im_SY...
# 68  http://books.google.com/books/content?id=9j2dE...
# 69  http://books.google.com/books/content?id=kTpwE...
# 70                                                NaN
# 71                                                NaN
#
#                       volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 0   http://books.google.com/books/content?id=Xq4hz...               DE
# 1   http://books.google.com/books/content?id=uiiVD...               DE
# 2   http://books.google.com/books/content?id=ySa-E...               DE
# 3   http://books.google.com/books/content?id=nGIGE...               DE
# 4                                                 NaN               DE
# ..                                                ...              ...
# 67  http://books.google.com/books/content?id=im_SY...               DE
# 68  http://books.google.com/books/content?id=9j2dE...               DE
# 69  http://books.google.com/books/content?id=kTpwE...               DE
# 70                                                NaN               DE
# 71                                                NaN               DE
#
#     saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 0                           NaN                               NaN
# 1                          9.49                               EUR
# 2                         18.99                               EUR
# 3                         10.99                               EUR
# 4                           NaN                               NaN
# ..                          ...                               ...
# 67                          NaN                               NaN
# 68                        12.99                               EUR
# 69                        14.99                               EUR
# 70                          NaN                               NaN
# 71                          NaN                               NaN
#
# [72 rows x 25 columns]

# %% [markdown]
# ## Update Notion with Google Data

# %%
# Update a property on a page based on property type
def update_page(page_id, property_name, property_type, property_value):
    url = f"https://api.notion.com/v1/pages/{page_id}"

    if property_type == 'date':
        property_payload = {
            "start": property_value
        }
    elif property_type == 'url':
        property_payload = property_value
    elif property_type == 'number':
        property_payload = property_value
    elif property_type == 'rich_text':
        property_payload = [{
            "type": "text",
            "text": {
                "content": property_value
            }
        }]
    elif property_type == 'select':
        property_payload = {
            "name": property_value
        }

    payload = json.dumps({
        "properties": {
            property_name: {
                property_type: property_payload
            }
        }
    })
    # print(payload)
    headers = {
        'Content-Type': 'application/json',
        'Notion-Version': '2021-05-13',
        'Authorization': f'Bearer {NOTION_SECRET}'
    }

    response = requests.request(
        "PATCH", url, headers=headers, data=payload)
    print(response.status_code)
    # print(response.json)
    return response.json

# %%
def update_properties(property_name, property_type, data_column, df, i):
    page_id = df['page_id'].iloc[i]
    property_value = df[data_column].iloc[i]
    update_page(page_id, property_name, property_type, property_value)

# %% [markdown]
# ### update publishing dates

# %%
# Update publishing dates
property_name = 'Publishing/Release Date'
property_type = "date"
data_column = 'volumeInfo.publishedDate'

for i in clean_google_data['page_id'].index:
    # if math.isnan(look_up['Publishing/Release Date'][i]):
    update_properties(property_name, property_type, data_column, complete, i)
# Out:
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[134], line 8
#       4 data_column = 'volumeInfo.publishedDate'
#       6 for i in clean_google_data['page_id'].index:
#       7     # if math.isnan(look_up['Publishing/Release Date'][i]):
# ----> 8     update_properties(property_name, property_type, data_column, complete, i)
#
# Cell In[130], line 2, in update_properties(property_name, property_type, data_column, df, i)
#       1 def update_properties(property_name, property_type, data_column, df, i):
# ----> 2     page_id = df['page_id'].iloc[i]
#       3     property_value = df[data_column].iloc[i]
#       4     update_page(page_id, property_name, property_type, property_value)
#
# File c:\Users\chris\Projects\Notion-Bookshelf\.venv\lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\chris\Projects\Notion-Bookshelf\.venv\lib\site-packages\pandas\core\indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# -> 1752 self._validate_integer(key, axis)
#    1754 return self.obj._ixs(key, axis=axis)
#
# File c:\Users\chris\Projects\Notion-Bookshelf\.venv\lib\site-packages\pandas\core\indexing.py:1685, in _iLocIndexer._validate_integer(self, key, axis)
#    1683 len_axis = len(self.obj._get_axis(axis))
#    1684 if key >= len_axis or key < -len_axis:
# -> 1685     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %% [markdown]
# Work on the update process
