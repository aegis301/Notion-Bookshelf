# %% [markdown]
# # Setup

# %%
import pandas as pd
import requests
import json
import math

# %%
def google_book_search(title, author, publisher):
    search_terms = " ".join(filter(None, [title, author, publisher]))
    url = 'https://www.googleapis.com/books/v1/volumes?q='
    response = requests.get(url+search_terms)
    data = response.json()
    # Normalizing data
    df = pd.json_normalize(data, record_path=['items'])
    return df


search_terms = "maniac labatut"
url = 'https://www.googleapis.com/books/v1/volumes?q='
response = requests.get(url+search_terms)
data = response.json()
# # Normalizing data
df = pd.json_normalize(data, record_path=['items'])

# %%
secret_key = ''
database_id = '1b71653e363148e0b2ba399638473ced'

# %%
def query_databases(secret_key, database_id):
    url = "https://api.notion.com/v1/databases/"+database_id+'/query'

    payload = {'id': database_id}
    headers = {
        'Notion-Version': '2021-05-13',
        'Authorization': 'Bearer '+secret_key
    }

    response = requests.request(
        "POST", url, headers=headers, data=payload)
    print(f"The response code is {response.status_code}")
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    else:
        return response.json()

# %%
res = query_databases(secret_key, database_id)
# Out:
# The response code is 200

# %%
res.get('results')[0].get('properties')[
    'Summary']['rich_text'][0].get('plain_text')
# Out:
# 'Dieses eBook: "Moby Dick" ist mit einem detaillierten und dynamischen Inhaltsverzeichnis versehen und wurde sorgfältig korrekturgelesen. Moby-Dick beginnt mit dem Satz: "Call me Ishmael." Es folgt die Ich-Erzählung des Matrosen Ismael (sein voller Name wird nie genannt), der aus einer angesehenen Familie stammt und sich entscheidet, als Matrose zur See zu fahren, um seiner Melancholie zu entfliehen. Er spricht von einem unbändigen Drang in ihm, der ihn überkomme, wenn er des Festlands überdrüssig sei. Ismael hat bereits einige Fahrten auf Handelsschiffen hinter sich, will nun aber auf einem Walfänger anheuern. Das erzählerische Rückgrat des Romans ist die schicksalhafte Fahrt des Walfangschiffes Pequod, dessen einbeiniger Kapitän Ahab mit blindem Hass den weißen Pottwal jagt, der ihm das Bein abgerissen hat. Entlang dieses erzählerischen Fadens reiht Melville zahlreiche philosophische, wissenschaftliche, kunstgeschichtliche und mythologische Exkurse. Dieses eBook ist eine Überarbeitung von Wilhelm Strüvers Übersetzung der Erstausgabe von 1927/28, wie sie von Thomas Mann herausgegeben wurde.'

# %%
notion_columns = ['Category', 'Publisher', 'Summary', 'Current page', 'Link',
                  'Total pages', 'Date started', 'Author', 'Title', 'url', 'page_id']
notion = pd.DataFrame(columns=notion_columns)
print(notion.columns)
print(notion.head())
for page in res.get('results'):
    properties = page.get('properties')
    try:
        author = properties.get('Author').get('rich_text')[0].get('plain_text')
    except IndexError:
        author = None
    try:
        title = properties.get('Title').get('title')[0].get('plain_text')
    except IndexError:
        title = None
    try:
        publisher = properties['Publisher']['select']['name']
    except KeyError:
        publisher = None
    try:
        category = properties['Category']['select']['name']
    except KeyError:
        category = None
    try:
        summary = properties['Summary']['rich_text'][0]['plain_text']
    except IndexError:
        summary = None
    try:
        current_page = properties['Current page']['number']
    except KeyError:
        current_page = None
    try:
        link = properties['Link']['url']
    except KeyError:
        link = None
    total_pages = properties['Total pages']['number']
    try:
        date_started = properties['Date started']['date']['start']
    except KeyError:
        date_started = None

    url = page.get('url')
    page_id = url[-32:]
    # concat the data
    notion = pd.concat([notion, pd.DataFrame([[category, publisher, summary, current_page, link, total_pages,
                       date_started, author, title, url, page_id]], columns=notion_columns)], ignore_index=True)
# drop rows without title
notion = notion.dropna(subset=['Title'])
# Out:
# Index(['Category', 'Publisher', 'Summary', 'Current page', 'Link',
#        'Total pages', 'Date started', 'Author', 'Title', 'url', 'page_id'],
#       dtype='object')
# Empty DataFrame
# Columns: [Category, Publisher, Summary, Current page, Link, Total pages, Date started, Author, Title, url, page_id]
# Index: []

# %%
google_results = pd.DataFrame()

for book in notion.itertuples():

    google_results = pd.concat([google_results, google_book_search(
        book.Title, book.Author, book.Publisher)], ignore_index=True)

# %%
google_data = google_results[['selfLink', 'volumeInfo.title',
                              'volumeInfo.subtitle', 'volumeInfo.authors', 'volumeInfo.publisher',
                              'volumeInfo.publishedDate', 'volumeInfo.description', 'volumeInfo.pageCount', 'volumeInfo.categories',
                              'volumeInfo.imageLinks.smallThumbnail', 'volumeInfo.imageLinks.thumbnail', 'saleInfo.country', 'saleInfo.retailPrice.amount',
                              'saleInfo.retailPrice.currencyCode'
                              ]]

# %%
import pandas as pd


def clean_google_data(google_df, notion_df):
    filtered_results = []

    for _, notion_row in notion_df.iterrows():
        try:
            # Filter google_df by title
            matches = google_df[google_df['volumeInfo.title']
                                == notion_row['Title']]
        except TypeError as e:
            print(f"TypeError encountered while filtering by title: {e}")
            continue

        try:
            # Further filter by author if available
            if pd.notna(notion_row.get('Author')):
                matches = matches[matches['volumeInfo.authors'].apply(
                    lambda authors: notion_row['Author'] in authors if authors else False)]
        except TypeError as e:
            print(f"TypeError encountered while filtering by author: {e}")
            continue

        try:
            # Further filter by publisher if available
            if pd.notna(notion_row.get('Publisher')):
                matches = matches[matches['volumeInfo.publisher']
                                  == notion_row['Publisher']]
        except TypeError as e:
            print(f"TypeError encountered while filtering by publisher: {e}")
            continue

        try:
            # If there are matches, keep the latest by published_date
            latest_match = matches.sort_values(
                by='volumeInfo.publishedDate', ascending=False).iloc[0]
            filtered_results.append(latest_match)
        except IndexError as e:
            # only single match, append
            print(f"Not match found for {notion_row['Title']}")
            continue
        except KeyError:
            print(f"Not match found for {notion_row['Title']}")
            continue

    # Convert the list of filtered results to a DataFrame
    filtered_df = pd.DataFrame(filtered_results)
    return filtered_df

# %%
clean_google_data = clean_google_data(google_data, notion)
# Out:
# Empty DataFrame
# Columns: [selfLink, volumeInfo.title, volumeInfo.subtitle, volumeInfo.authors, volumeInfo.publisher, volumeInfo.publishedDate, volumeInfo.description, volumeInfo.pageCount, volumeInfo.categories, volumeInfo.imageLinks.smallThumbnail, volumeInfo.imageLinks.thumbnail, saleInfo.country, saleInfo.retailPrice.amount, saleInfo.retailPrice.currencyCode]
# Index: []
# Not match found for Moby Dick
# Empty DataFrame
# Columns: [selfLink, volumeInfo.title, volumeInfo.subtitle, volumeInfo.authors, volumeInfo.publisher, volumeInfo.publishedDate, volumeInfo.description, volumeInfo.pageCount, volumeInfo.categories, volumeInfo.imageLinks.smallThumbnail, volumeInfo.imageLinks.thumbnail, saleInfo.country, saleInfo.retailPrice.amount, saleInfo.retailPrice.currencyCode]
# Index: []
# Not match found for Winterbienen
# TypeError encountered while filtering by author: argument of type 'float' is not iterable
#                                              selfLink volumeInfo.title  \
# 30  https://www.googleapis.com/books/v1/volumes/nG...    Über Menschen
#
#    volumeInfo.subtitle volumeInfo.authors         volumeInfo.publisher  \
# 30               Roman         [Juli Zeh]  Luchterhand Literaturverlag
#
#    volumeInfo.publishedDate  \
# 30               2021-03-22
#
#                                volumeInfo.description  volumeInfo.pageCount  \
# 30  Dora ist mit ihrer kleinen Hündin aufs Land ge...                 351.0
#
#    volumeInfo.categories               volumeInfo.imageLinks.smallThumbnail  \
# 30             [Fiction]  http://books.google.com/books/content?id=nGIGE...
#
#                       volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 30  http://books.google.com/books/content?id=nGIGE...               DE
#
#     saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 30                        10.99                               EUR
#                                              selfLink volumeInfo.title  \
# 40  https://www.googleapis.com/books/v1/volumes/mk...          Zur See
# 41  https://www.googleapis.com/books/v1/volumes/cQ...          Zur See
# 45  https://www.googleapis.com/books/v1/volumes/vZ...          Zur See
#
#                 volumeInfo.subtitle volumeInfo.authors  \
# 40  Roman - Der Nummer 1 Bestseller     [Dörte Hansen]
# 41                            Roman     [Dörte Hansen]
# 45                              NaN     [Dörte Hansen]
#
#                volumeInfo.publisher volumeInfo.publishedDate  \
# 40  Verlagsgruppe Random House GmbH               2022-09-28
# 41                              NaN               2022-09-28
# 45                              NaN                     2022
#
#                                volumeInfo.description  volumeInfo.pageCount  \
# 40  Der dritte Roman von Bestsellerautorin Dörte H...                 193.0
# 41                                                NaN                 208.0
# 45                                                NaN                   0.0
#
#    volumeInfo.categories               volumeInfo.imageLinks.smallThumbnail  \
# 40             [Fiction]  http://books.google.com/books/content?id=mkVnE...
# 41                   NaN                                                NaN
# 45                   NaN                                                NaN
#
#                       volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 40  http://books.google.com/books/content?id=mkVnE...               DE
# 41                                                NaN               DE
# 45                                                NaN               DE
#
#     saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 40                        14.99                               EUR
# 41                          NaN                               NaN
# 45                          NaN                               NaN
# Empty DataFrame
# Columns: []
# Index: []
# Not match found for The Illustrated A Brief History of Time
#                                              selfLink       volumeInfo.title  \
# 63  https://www.googleapis.com/books/v1/volumes/0N...  To Kill a Mockingbird
# 68  https://www.googleapis.com/books/v1/volumes/nc...  To Kill a Mockingbird
#
#    volumeInfo.subtitle volumeInfo.authors              volumeInfo.publisher  \
# 63                 NaN       [Harper Lee]               Dramatic Publishing
# 68                 NaN       [Harper Lee]  Harper Perennial Modern Classics
#
#    volumeInfo.publishedDate  \
# 63                     1970
# 68               2006-05-23
#
#                                volumeInfo.description  volumeInfo.pageCount  \
# 63  Harper Lee's classic novel of a lawyer in the ...                  98.0
# 68  Harper Lee's Pulitzer Prize-winning masterwork...                 346.0
#
#       volumeInfo.categories  \
# 63  [Fathers and daughters]
# 68                [Fiction]
#
#                  volumeInfo.imageLinks.smallThumbnail  \
# 63  http://books.google.com/books/content?id=0NEbH...
# 68  http://books.google.com/books/content?id=ncuX8...
#
#                       volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 63  http://books.google.com/books/content?id=0NEbH...               DE
# 68  http://books.google.com/books/content?id=ncuX8...               DE
#
#     saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 63                          NaN                               NaN
# 68                          NaN                               NaN
#                                              selfLink volumeInfo.title  \
# 70  https://www.googleapis.com/books/v1/volumes/tr...   The Innovators
# 71  https://www.googleapis.com/books/v1/volumes/vR...   The Innovators
# 72  https://www.googleapis.com/books/v1/volumes/9n...   The Innovators
# 74  https://www.googleapis.com/books/v1/volumes/cH...   The Innovators
#
#                                   volumeInfo.subtitle  \
# 70  How a Group of Hackers, Geniuses, and Geeks Cr...
# 71  Die Vordenker der digitalen Revolution von Ada...
# 72  How a Group of Inventors, Hackers, Geniuses an...
# 74  How a Group of Inventors, Hackers, Geniuses an...
#
#                     volumeInfo.authors   volumeInfo.publisher  \
# 70                   [Walter Isaacson]     Simon and Schuster
# 71                   [Walter Isaacson]  C. Bertelsmann Verlag
# 72                   [Walter Isaacson]     Simon and Schuster
# 74  [To Be Announced, Walter Isaacson]       Simon & Schuster
#
#    volumeInfo.publishedDate  \
# 70               2014-10-07
# 71               2018-04-23
# 72               2014-10-07
# 74                  2014-10
#
#                                volumeInfo.description  volumeInfo.pageCount  \
# 70  Following his blockbuster biography of Steve J...                 560.0
# 71  Sind sie jetzt Nerds, Weltverbesserer oder Spi...                 479.0
# 72  Following his blockbuster biography of Steve J...                 788.0
# 74  Following his blockbuster biography of Steve J...                 528.0
#
#           volumeInfo.categories  \
# 70   [Technology & Engineering]
# 71  [Biography & Autobiography]
# 72  [Biography & Autobiography]
# 74           [Computer science]
#
#                  volumeInfo.imageLinks.smallThumbnail  \
# 70  http://books.google.com/books/content?id=trxEA...
# 71  http://books.google.com/books/content?id=vRs-D...
# 72  http://books.google.com/books/content?id=9nd0A...
# 74  http://books.google.com/books/content?id=cHVtv...
#
#                       volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 70  http://books.google.com/books/content?id=trxEA...               DE
# 71  http://books.google.com/books/content?id=vRs-D...               DE
# 72  http://books.google.com/books/content?id=9nd0A...               DE
# 74  http://books.google.com/books/content?id=cHVtv...               DE
#
#     saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 70                        15.81                               EUR
# 71                        19.99                               EUR
# 72                          NaN                               NaN
# 74                          NaN                               NaN
#                                              selfLink  volumeInfo.title  \
# 82  https://www.googleapis.com/books/v1/volumes/GU...  The Code Breaker
#
#                                   volumeInfo.subtitle volumeInfo.authors  \
# 82  Jennifer Doudna, Gene Editing, and the Future ...  [Walter Isaacson]
#
#    volumeInfo.publisher volumeInfo.publishedDate  \
# 82   Simon and Schuster               2022-05-03
#
#                                volumeInfo.description  volumeInfo.pageCount  \
# 82  "A gripping account of how the pioneering scie...                 560.0
#
#           volumeInfo.categories  \
# 82  [Biography & Autobiography]
#
#                  volumeInfo.imageLinks.smallThumbnail  \
# 82  http://books.google.com/books/content?id=GUSFE...
#
#                       volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 82  http://books.google.com/books/content?id=GUSFE...               DE
#
#     saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 82                          NaN                               NaN
# Empty DataFrame
# Columns: [selfLink, volumeInfo.title, volumeInfo.subtitle, volumeInfo.authors, volumeInfo.publisher, volumeInfo.publishedDate, volumeInfo.description, volumeInfo.pageCount, volumeInfo.categories, volumeInfo.imageLinks.smallThumbnail, volumeInfo.imageLinks.thumbnail, saleInfo.country, saleInfo.retailPrice.amount, saleInfo.retailPrice.currencyCode]
# Index: []
# Not match found for Sportbootführerschein Binnen Segel/Motor
#                                               selfLink       volumeInfo.title  \
# 102  https://www.googleapis.com/books/v1/volumes/el...  The Children of Hurin
#
#     volumeInfo.subtitle  volumeInfo.authors volumeInfo.publisher  \
# 102                 NaN  [J. R. R. Tolkien]        Mariner Books
#
#     volumeInfo.publishedDate  \
# 102                  2008-10
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 102  A fantasy adventure saga set in the early days...                 313.0
#
#     volumeInfo.categories               volumeInfo.imageLinks.smallThumbnail  \
# 102             [Fiction]  http://books.google.com/books/content?id=eldcP...
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 102  http://books.google.com/books/content?id=eldcP...               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 102                          NaN                               NaN
#                                               selfLink volumeInfo.title  \
# 110  https://www.googleapis.com/books/v1/volumes/gW...    Sei du selbst
# 111  https://www.googleapis.com/books/v1/volumes/qG...    Sei du selbst
#
#               volumeInfo.subtitle      volumeInfo.authors  \
# 110  Geschichte der Philosophie 3  [Richard David Precht]
# 111  Geschichte der Philosophie 3  [Richard David Precht]
#
#     volumeInfo.publisher volumeInfo.publishedDate  \
# 110      Goldmann Verlag               2019-10-14
# 111                  NaN                      NaN
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 110  Der lang erwartete dritte Band von Prechts fün...                 503.0
# 111                                                NaN                 420.0
#
#     volumeInfo.categories               volumeInfo.imageLinks.smallThumbnail  \
# 110          [Philosophy]  http://books.google.com/books/content?id=gWaiC...
# 111                   NaN  http://books.google.com/books/content?id=qGpxr...
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 110  http://books.google.com/books/content?id=gWaiC...               DE
# 111  http://books.google.com/books/content?id=qGpxr...               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 110                        19.99                               EUR
# 111                          NaN                               NaN
#                                               selfLink volumeInfo.title  \
# 121  https://www.googleapis.com/books/v1/volumes/a_...      Prima facie
#
#     volumeInfo.subtitle volumeInfo.authors            volumeInfo.publisher  \
# 121             A novel     [Suzie Miller]  Carl Hanser Verlag GmbH  Co KG
#
#     volumeInfo.publishedDate  \
# 121               2024-01-29
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 121  Das Gesetz ist dazu da, ALLE Menschen zu besch...                 320.0
#
#     volumeInfo.categories               volumeInfo.imageLinks.smallThumbnail  \
# 121             [Fiction]  http://books.google.com/books/content?id=a_LnE...
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 121  http://books.google.com/books/content?id=a_LnE...               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 121                        18.99                               EUR
#                                               selfLink volumeInfo.title  \
# 130  https://www.googleapis.com/books/v1/volumes/g9...             SPQR
# 132  https://www.googleapis.com/books/v1/volumes/x7...             SPQR
#
#                     volumeInfo.subtitle volumeInfo.authors  \
# 130  Die tausendjährige Geschichte Roms       [Mary Beard]
# 132           A History of Ancient Rome       [Mary Beard]
#
#     volumeInfo.publisher volumeInfo.publishedDate  \
# 130    S. Fischer Verlag               2016-10-13
# 132        Profile Books               2015-10-20
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 130  Die Geschichte Roms für unsere Zeit: Wer hätte...                 774.0
# 132  Mary Beard's new book Emperor of Rome is avail...                 425.0
#
#     volumeInfo.categories               volumeInfo.imageLinks.smallThumbnail  \
# 130             [History]  http://books.google.com/books/content?id=g9ARD...
# 132             [History]  http://books.google.com/books/content?id=x795C...
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 130  http://books.google.com/books/content?id=g9ARD...               DE
# 132  http://books.google.com/books/content?id=x795C...               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 130                         5.99                               EUR
# 132                        10.99                               EUR
# Empty DataFrame
# Columns: [selfLink, volumeInfo.title, volumeInfo.subtitle, volumeInfo.authors, volumeInfo.publisher, volumeInfo.publishedDate, volumeInfo.description, volumeInfo.pageCount, volumeInfo.categories, volumeInfo.imageLinks.smallThumbnail, volumeInfo.imageLinks.thumbnail, saleInfo.country, saleInfo.retailPrice.amount, saleInfo.retailPrice.currencyCode]
# Index: []
# Not match found for Praxisbuch Usability & UX
#                                               selfLink volumeInfo.title  \
# 150  https://www.googleapis.com/books/v1/volumes/p3...       Offene See
#
#     volumeInfo.subtitle volumeInfo.authors volumeInfo.publisher  \
# 150               Roman   [Benjamin Myers]    Dumont Buchverlag
#
#     volumeInfo.publishedDate  \
# 150               2020-03-20
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 150  Eine zeitlose und geradezu zärtliche Geschicht...                 234.0
#
#     volumeInfo.categories               volumeInfo.imageLinks.smallThumbnail  \
# 150             [Fiction]  http://books.google.com/books/content?id=p3nAD...
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 150  http://books.google.com/books/content?id=p3nAD...               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 150                         9.99                               EUR
#                                               selfLink volumeInfo.title  \
# 160  https://www.googleapis.com/books/v1/volumes/T7...       Noch wach?
#
#     volumeInfo.subtitle             volumeInfo.authors  volumeInfo.publisher  \
# 160               Roman  [Benjamin von Stuckrad-Barre]  Kiepenheuer & Witsch
#
#     volumeInfo.publishedDate  \
# 160               2023-04-22
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 160  Berlin: Eine junge Frau erzählt von ihrem neue...                 365.0
#
#     volumeInfo.categories               volumeInfo.imageLinks.smallThumbnail  \
# 160             [Fiction]  http://books.google.com/books/content?id=T7y6E...
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 160  http://books.google.com/books/content?id=T7y6E...               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 160                        19.99                               EUR
# Empty DataFrame
# Columns: [selfLink, volumeInfo.title, volumeInfo.subtitle, volumeInfo.authors, volumeInfo.publisher, volumeInfo.publishedDate, volumeInfo.description, volumeInfo.pageCount, volumeInfo.categories, volumeInfo.imageLinks.smallThumbnail, volumeInfo.imageLinks.thumbnail, saleInfo.country, saleInfo.retailPrice.amount, saleInfo.retailPrice.currencyCode]
# Index: []
# Not match found for Physik
#                                               selfLink  \
# 180  https://www.googleapis.com/books/v1/volumes/U7...
#
#                volumeInfo.title volumeInfo.subtitle volumeInfo.authors  \
# 180  Nachrichten aus Mittelerde                 NaN   [J.R.R. Tolkien]
#
#     volumeInfo.publisher volumeInfo.publishedDate  \
# 180          Klett Cotta               2012-03-15
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 180  Verstreute Nachrichten, vergessen geglaubte Ge...                 630.0
#
#     volumeInfo.categories               volumeInfo.imageLinks.smallThumbnail  \
# 180             [Fiction]  http://books.google.com/books/content?id=U7W5w...
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 180  http://books.google.com/books/content?id=U7W5w...               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 180                        14.99                               EUR
#                                               selfLink  \
# 190  https://www.googleapis.com/books/v1/volumes/52...
# 191  https://www.googleapis.com/books/v1/volumes/jD...
# 192  https://www.googleapis.com/books/v1/volumes/SM...
# 193  https://www.googleapis.com/books/v1/volumes/ZK...
# 197  https://www.googleapis.com/books/v1/volumes/FZ...
# 199  https://www.googleapis.com/books/v1/volumes/v2...
#
#             volumeInfo.title  \
# 190  Napoleon und seine Zeit
# 191  Napoleon und seine Zeit
# 192  Napoleon und seine Zeit
# 193  Napoleon und seine Zeit
# 197  Napoleon und seine Zeit
# 199  Napoleon und seine Zeit
#
#                                    volumeInfo.subtitle  \
# 190                                                NaN
# 191                                                NaN
# 192                          Katalog 168. (Bonaparte.)
# 193                                          1769-1821
# 197  1769 - 1821 ; Kaiser der Franzosen ; Herrscher...
# 199                                                NaN
#
#                volumeInfo.authors volumeInfo.publisher  \
# 190                           NaN                  NaN
# 191               [Mario Rivoire]                  NaN
# 192          [Karl W. Hiersemann]                  NaN
# 193                           NaN                  NaN
# 197                           NaN                  NaN
# 199  [Octave Aubry, Hans Dühring]                  NaN
#
#     volumeInfo.publishedDate volumeInfo.description  volumeInfo.pageCount  \
# 190                     1968                    NaN                  75.0
# 191                  1965-01                    NaN                  75.0
# 192                     1896                    NaN                  26.0
# 193                     2012                    NaN                   0.0
# 197                     2012                    NaN                 170.0
# 199                     1938                    NaN                 283.0
#
#     volumeInfo.categories               volumeInfo.imageLinks.smallThumbnail  \
# 190                   NaN                                                NaN
# 191              [France]                                                NaN
# 192                   NaN  http://books.google.com/books/content?id=SMdR9...
# 193                   NaN                                                NaN
# 197                   NaN                                                NaN
# 199                   NaN                                                NaN
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 190                                                NaN               DE
# 191                                                NaN               DE
# 192  http://books.google.com/books/content?id=SMdR9...               DE
# 193                                                NaN               DE
# 197                                                NaN               DE
# 199                                                NaN               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 190                          NaN                               NaN
# 191                          NaN                               NaN
# 192                          NaN                               NaN
# 193                          NaN                               NaN
# 197                          NaN                               NaN
# 199                          NaN                               NaN
#                                               selfLink volumeInfo.title  \
# 200  https://www.googleapis.com/books/v1/volumes/0E...      Montecristo
# 202  https://www.googleapis.com/books/v1/volumes/je...      Montecristo
# 205  https://www.googleapis.com/books/v1/volumes/4C...      Montecristo
#
#     volumeInfo.subtitle volumeInfo.authors       volumeInfo.publisher  \
# 200               Roman     [Martin Suter]                        NaN
# 202                 NaN     [Martin Suter]  Bedford Square Publishers
# 205                 NaN     [Martin Suter]         Diogenes Verlag AG
#
#     volumeInfo.publishedDate  \
# 200               2015-02-25
# 202               2016-06-22
# 205               2015-02-25
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 200  Ein Personenschaden bei einer Fahrt im Interci...                 308.0
# 202  Video journalist Jonas Brand is on a rail jour...                 283.0
# 205  Eigentlich möchte Jonas Brand nur sein Filmpro...                 249.0
#
#     volumeInfo.categories               volumeInfo.imageLinks.smallThumbnail  \
# 200    [Photojournalists]  http://books.google.com/books/content?id=0E8No...
# 202             [Fiction]  http://books.google.com/books/content?id=jerVE...
# 205             [Fiction]  http://books.google.com/books/content?id=4COaB...
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 200  http://books.google.com/books/content?id=0E8No...               DE
# 202  http://books.google.com/books/content?id=jerVE...               DE
# 205  http://books.google.com/books/content?id=4COaB...               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 200                          NaN                               NaN
# 202                         9.99                               EUR
# 205                        10.99                               EUR
# Empty DataFrame
# Columns: [selfLink, volumeInfo.title, volumeInfo.subtitle, volumeInfo.authors, volumeInfo.publisher, volumeInfo.publishedDate, volumeInfo.description, volumeInfo.pageCount, volumeInfo.categories, volumeInfo.imageLinks.smallThumbnail, volumeInfo.imageLinks.thumbnail, saleInfo.country, saleInfo.retailPrice.amount, saleInfo.retailPrice.currencyCode]
# Index: []
# Not match found for My Own Words
#                                               selfLink volumeInfo.title  \
# 17   https://www.googleapis.com/books/v1/volumes/KD...          Mutabor
# 220  https://www.googleapis.com/books/v1/volumes/KD...          Mutabor
# 221  https://www.googleapis.com/books/v1/volumes/wM...          Mutabor
#
#     volumeInfo.subtitle volumeInfo.authors volumeInfo.publisher  \
# 17                Roman  [Norbert Scheuer]             C.H.Beck
# 220               Roman  [Norbert Scheuer]             C.H.Beck
# 221               Roman  [Norbert Scheuer]                  NaN
#
#     volumeInfo.publishedDate  \
# 17                2022-07-14
# 220               2022-07-14
# 221               2022-08-25
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 17   Die junge, elternlose Nina Plisson weiß nicht,...                 198.0
# 220  Die junge, elternlose Nina Plisson weiß nicht,...                 198.0
# 221                                                NaN                 176.0
#
#     volumeInfo.categories               volumeInfo.imageLinks.smallThumbnail  \
# 17              [Fiction]  http://books.google.com/books/content?id=KDd0E...
# 220             [Fiction]  http://books.google.com/books/content?id=KDd0E...
# 221                   NaN                                                NaN
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 17   http://books.google.com/books/content?id=KDd0E...               DE
# 220  http://books.google.com/books/content?id=KDd0E...               DE
# 221                                                NaN               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 17                         16.99                               EUR
# 220                        16.99                               EUR
# 221                          NaN                               NaN
#                                               selfLink volumeInfo.title  \
# 230  https://www.googleapis.com/books/v1/volumes/IP...         Monschau
# 231  https://www.googleapis.com/books/v1/volumes/T6...         Monschau
#
#     volumeInfo.subtitle  volumeInfo.authors volumeInfo.publisher  \
# 230                 NaN  [Steffen Kopetzky]  Rowohlt Verlag GmbH
# 231               Roman  [Steffen Kopetzky]                  NaN
#
#     volumeInfo.publishedDate  \
# 230               2021-03-23
# 231                     2021
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 230  Im Jahr 1962, als das nukleare Wettrüsten sein...                 230.0
# 231                                                NaN                   NaN
#
#     volumeInfo.categories               volumeInfo.imageLinks.smallThumbnail  \
# 230             [Fiction]  http://books.google.com/books/content?id=IPQIE...
# 231                   NaN                                                NaN
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 230  http://books.google.com/books/content?id=IPQIE...               DE
# 231                                                NaN               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 230                         9.99                               EUR
# 231                          NaN                               NaN
#                                               selfLink volumeInfo.title  \
# 240  https://www.googleapis.com/books/v1/volumes/W9...      MONEYMAKERS
# 241  https://www.googleapis.com/books/v1/volumes/hh...      MONEYMAKERS
#
#                                    volumeInfo.subtitle volumeInfo.authors  \
# 240         Wie du die Börse für dich entdecken kannst         [Aya Jaff]
# 241  Deine ersten Schritte an der Börse und was du ...         [Aya Jaff]
#
#     volumeInfo.publisher volumeInfo.publishedDate  \
# 240    FinanzBuch Verlag               2020-05-09
# 241                  NaN                  2018-05
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 240  MONEY MAKERS zeigt dir, wie du den Schritt an ...                 197.0
# 241                                                NaN                 200.0
#
#       volumeInfo.categories  \
# 240  [Business & Economics]
# 241                     NaN
#
#                   volumeInfo.imageLinks.smallThumbnail  \
# 240  http://books.google.com/books/content?id=W9DID...
# 241  http://books.google.com/books/content?id=hhL6s...
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 240  http://books.google.com/books/content?id=W9DID...               DE
# 241  http://books.google.com/books/content?id=hhL6s...               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 240                        13.99                               EUR
# 241                          NaN                               NaN
#                                               selfLink volumeInfo.title  \
# 250  https://www.googleapis.com/books/v1/volumes/ri...    Madame Bovary
# 251  https://www.googleapis.com/books/v1/volumes/G_...    Madame Bovary
# 256  https://www.googleapis.com/books/v1/volumes/4m...    Madame Bovary
# 259  https://www.googleapis.com/books/v1/volumes/FK...    Madame Bovary
#
#                                    volumeInfo.subtitle  \
# 250                                              Roman
# 251                                                NaN
# 256  ein Sittenbild aus der Provinz von Gustave Fla...
# 259                                                NaN
#
#                            volumeInfo.authors  \
# 250                        [Gustave Flaubert]
# 251                        [Gustave Flaubert]
# 256                        [Gustave Flaubert]
# 259  [Gustave Flaubert, Eleanor Marx Aveling]
#
#                  volumeInfo.publisher volumeInfo.publishedDate  \
# 250    Carl Hanser Verlag GmbH  Co KG               2012-09-24
# 251                   Jazzybee Verlag               2015-05-04
# 256                               NaN                     1896
# 259  E-Kitap Projesi & Cheapest Books               2024-01-23
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 250  Gustave Flauberts hinreißendes Drama und seine...                 752.0
# 251  Madame Bovary, in älteren Übersetzungen auch F...                 329.0
# 256                                                NaN                   NaN
# 259  Madame Bovary takes place in provincial northe...                 499.0
#
#     volumeInfo.categories               volumeInfo.imageLinks.smallThumbnail  \
# 250             [Fiction]  http://books.google.com/books/content?id=riFQA...
# 251             [Fiction]  http://books.google.com/books/content?id=G_RDD...
# 256                   NaN                                                NaN
# 259             [Fiction]  http://books.google.com/books/content?id=FKHuE...
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 250  http://books.google.com/books/content?id=riFQA...               DE
# 251  http://books.google.com/books/content?id=G_RDD...               DE
# 256                                                NaN               DE
# 259  http://books.google.com/books/content?id=FKHuE...               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 250                        14.99                               EUR
# 251                          NaN                               NaN
# 256                          NaN                               NaN
# 259                         4.99                               EUR
#                                               selfLink volumeInfo.title  \
# 260  https://www.googleapis.com/books/v1/volumes/tI...       Lichtspiel
# 261  https://www.googleapis.com/books/v1/volumes/qi...       Lichtspiel
#
#                                    volumeInfo.subtitle volumeInfo.authors  \
# 260  Roman | "Ein Geniestreich von einem Roman, ein...  [Daniel Kehlmann]
# 261                                                NaN  [Daniel Kehlmann]
#
#     volumeInfo.publisher volumeInfo.publishedDate  \
# 260  Rowohlt Verlag GmbH               2023-10-10
# 261                  NaN               2023-10-10
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 260  Einer der Größten des Kinos, vielleicht der gr...                 440.0
# 261                                                NaN                   0.0
#
#     volumeInfo.categories               volumeInfo.imageLinks.smallThumbnail  \
# 260             [Fiction]  http://books.google.com/books/content?id=tIm2E...
# 261                   NaN                                                NaN
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 260  http://books.google.com/books/content?id=tIm2E...               DE
# 261                                                NaN               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 260                        22.99                               EUR
# 261                          NaN                               NaN
#                                               selfLink volumeInfo.title  \
# 270  https://www.googleapis.com/books/v1/volumes/zH...           MANIAC
# 272  https://www.googleapis.com/books/v1/volumes/X8...           MANIAC
# 276  https://www.googleapis.com/books/v1/volumes/2C...           MANIAC
# 277  https://www.googleapis.com/books/v1/volumes/WX...           MANIAC
#
#                                    volumeInfo.subtitle  volumeInfo.authors  \
# 270                                                NaN  [Benjamín Labatut]
# 272  Roman | Mensch vs. Maschine | Für alle Fans vo...  [Benjamín Labatut]
# 276                                              Roman  [Benjamín Labatut]
# 277                                              Roman  [Benjamín Labatut]
#
#     volumeInfo.publisher volumeInfo.publishedDate  \
# 270             Anagrama               2023-10-25
# 272      Suhrkamp Verlag               2023-09-24
# 276                  NaN                     2024
# 277                  NaN               2023-09-25
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 270  Una novela vertiginosa sobre los límites del p...                 236.0
# 272  Ein visionärer Roman über die Ursprünge und Zu...                 308.0
# 276                                                NaN                   0.0
# 277                                                NaN                   0.0
#
#     volumeInfo.categories               volumeInfo.imageLinks.smallThumbnail  \
# 270             [History]  http://books.google.com/books/content?id=zH3aE...
# 272             [Fiction]  http://books.google.com/books/content?id=X8y2E...
# 276                   NaN                                                NaN
# 277                   NaN                                                NaN
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 270  http://books.google.com/books/content?id=zH3aE...               DE
# 272  http://books.google.com/books/content?id=X8y2E...               DE
# 276                                                NaN               DE
# 277                                                NaN               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 270                         9.09                               EUR
# 272                        21.99                               EUR
# 276                          NaN                               NaN
# 277                          NaN                               NaN
#                                               selfLink   volumeInfo.title  \
# 280  https://www.googleapis.com/books/v1/volumes/yl...  Leonardo da Vinci
# 281  https://www.googleapis.com/books/v1/volumes/67...  Leonardo da Vinci
# 283  https://www.googleapis.com/books/v1/volumes/9A...  Leonardo da Vinci
#
#     volumeInfo.subtitle volumeInfo.authors  volumeInfo.publisher  \
# 280      Die Biographie  [Walter Isaacson]  Ullstein Buchverlage
# 281                 NaN  [Walter Isaacson]    Simon and Schuster
# 283      Die Biographie  [Walter Isaacson]                   NaN
#
#     volumeInfo.publishedDate  \
# 280               2018-10-26
# 281               2017-10-17
# 283               2019-11-29
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 280  Unehelich, Vegetarier, homosexuell, Linkshände...                 739.0
# 281  The #1 New York Times bestseller from Walter I...                 624.0
# 283                                                NaN                 752.0
#
#            volumeInfo.categories  \
# 280  [Biography & Autobiography]
# 281  [Biography & Autobiography]
# 283  [Biography & Autobiography]
#
#                   volumeInfo.imageLinks.smallThumbnail  \
# 280  http://books.google.com/books/content?id=ylFaD...
# 281  http://books.google.com/books/content?id=67KuD...
# 283                                                NaN
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 280  http://books.google.com/books/content?id=ylFaD...               DE
# 281  http://books.google.com/books/content?id=67KuD...               DE
# 283                                                NaN               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 280                        24.99                               EUR
# 281                        14.83                               EUR
# 283                          NaN                               NaN
#                                               selfLink   volumeInfo.title  \
# 291  https://www.googleapis.com/books/v1/volumes/Iy...  Krieg und Frieden
#
#     volumeInfo.subtitle volumeInfo.authors volumeInfo.publisher  \
# 291                 NaN      [Leo Tolstoi]   Null Papier Verlag
#
#     volumeInfo.publishedDate  \
# 291               2019-05-27
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 291  Zwischen 1863 und 1869 schuf Leo Tolstoi diese...                1785.0
#
#     volumeInfo.categories               volumeInfo.imageLinks.smallThumbnail  \
# 291             [Fiction]  http://books.google.com/books/content?id=Iyq6D...
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 291  http://books.google.com/books/content?id=Iyq6D...               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 291                         0.99                               EUR
#                                               selfLink     volumeInfo.title  \
# 300  https://www.googleapis.com/books/v1/volumes/VZ...  Klara und die Sonne
#
#     volumeInfo.subtitle volumeInfo.authors  volumeInfo.publisher  \
# 300               Roman   [Kazuo Ishiguro]  Karl Blessing Verlag
#
#     volumeInfo.publishedDate  \
# 300               2021-03-15
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 300  Der neue Roman des Nobelpreisträgers Klara ist...                 265.0
#
#     volumeInfo.categories               volumeInfo.imageLinks.smallThumbnail  \
# 300             [Fiction]  http://books.google.com/books/content?id=VZTwD...
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 300  http://books.google.com/books/content?id=VZTwD...               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 300                        12.99                               EUR
#                                               selfLink volumeInfo.title  \
# 310  https://www.googleapis.com/books/v1/volumes/3Z...     King: A Life
#
#     volumeInfo.subtitle volumeInfo.authors       volumeInfo.publisher  \
# 310                 NaN     [Jonathan Eig]  Farrar, Straus and Giroux
#
#     volumeInfo.publishedDate  \
# 310               2023-05-16
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 310  WINNER OF THE 2024 PULITZER PRIZE FOR BIOGRAPH...                 453.0
#
#            volumeInfo.categories  \
# 310  [Biography & Autobiography]
#
#                   volumeInfo.imageLinks.smallThumbnail  \
# 310  http://books.google.com/books/content?id=3ZyDE...
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 310  http://books.google.com/books/content?id=3ZyDE...               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 310                        23.95                               EUR
#                                               selfLink volumeInfo.title  \
# 320  https://www.googleapis.com/books/v1/volumes/px...    Ich bin Circe
#
#                                    volumeInfo.subtitle volumeInfo.authors  \
# 320  Roman | Eine rebellische Neuerzählung des Myth...  [Madeline Miller]
#
#      volumeInfo.publisher volumeInfo.publishedDate  \
# 320  Ullstein Buchverlage               2019-08-30
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 320  Unsterblich. Unvollkommen. Unbezähmbar. Circe ...                 493.0
#
#     volumeInfo.categories               volumeInfo.imageLinks.smallThumbnail  \
# 320             [Fiction]  http://books.google.com/books/content?id=pxKTD...
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 320  http://books.google.com/books/content?id=pxKTD...               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 320                        14.99                               EUR
#                                               selfLink volumeInfo.title  \
# 331  https://www.googleapis.com/books/v1/volumes/R7...        Humankind
#
#     volumeInfo.subtitle volumeInfo.authors   volumeInfo.publisher  \
# 331   A Hopeful History   [Rutger Bregman]  Bloomsbury Publishing
#
#     volumeInfo.publishedDate  \
# 331               2020-05-19
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 331  THE SUNDAY TIMES AND NEW YORK TIMES BESTSELLER...                 496.0
#
#       volumeInfo.categories  \
# 331  [Business & Economics]
#
#                   volumeInfo.imageLinks.smallThumbnail  \
# 331  http://books.google.com/books/content?id=R7rED...
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 331  http://books.google.com/books/content?id=R7rED...               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 331                         7.03                               EUR
# Empty DataFrame
# Columns: [selfLink, volumeInfo.title, volumeInfo.subtitle, volumeInfo.authors, volumeInfo.publisher, volumeInfo.publishedDate, volumeInfo.description, volumeInfo.pageCount, volumeInfo.categories, volumeInfo.imageLinks.smallThumbnail, volumeInfo.imageLinks.thumbnail, saleInfo.country, saleInfo.retailPrice.amount, saleInfo.retailPrice.currencyCode]
# Index: []
# Not match found for J. Robert Oppenheimer
#                                               selfLink  \
# 350  https://www.googleapis.com/books/v1/volumes/6Z...
#
#                     volumeInfo.title  \
# 350  How to Avoid a Climate Disaster
#
#                                    volumeInfo.subtitle volumeInfo.authors  \
# 350  The Solutions We Have and the Breakthroughs We...       [Bill Gates]
#
#     volumeInfo.publisher volumeInfo.publishedDate  \
# 350           Penguin UK               2021-02-16
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 350  In this urgent, authoritative book, Bill Gates...                 175.0
#
#     volumeInfo.categories               volumeInfo.imageLinks.smallThumbnail  \
# 350             [Science]  http://books.google.com/books/content?id=6Z6zD...
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 350  http://books.google.com/books/content?id=6Z6zD...               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 350                         9.49                               EUR
# Empty DataFrame
# Columns: [selfLink, volumeInfo.title, volumeInfo.subtitle, volumeInfo.authors, volumeInfo.publisher, volumeInfo.publishedDate, volumeInfo.description, volumeInfo.pageCount, volumeInfo.categories, volumeInfo.imageLinks.smallThumbnail, volumeInfo.imageLinks.thumbnail, saleInfo.country, saleInfo.retailPrice.amount, saleInfo.retailPrice.currencyCode]
# Index: []
# Not match found for How Democracies Die
#                                               selfLink volumeInfo.title  \
# 370  https://www.googleapis.com/books/v1/volumes/sF...            Homer
#
#     volumeInfo.subtitle    volumeInfo.authors volumeInfo.publisher  \
# 370     eine Einführung  [Gustav Adolf Seeck]                  NaN
#
#     volumeInfo.publishedDate volumeInfo.description  volumeInfo.pageCount  \
# 370                     2004                    NaN                 300.0
#
#     volumeInfo.categories               volumeInfo.imageLinks.smallThumbnail  \
# 370  [Epic poetry, Greek]  http://books.google.com/books/content?id=sFpiA...
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 370  http://books.google.com/books/content?id=sFpiA...               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 370                          NaN                               NaN
#                                               selfLink  \
# 380  https://www.googleapis.com/books/v1/volumes/cB...
# 381  https://www.googleapis.com/books/v1/volumes/FE...
#
#                     volumeInfo.title                     volumeInfo.subtitle  \
# 380  Hamster im hinteren Stromgebiet  Roman. Alle Toten fliegen hoch, Teil 5
# 381  Hamster im hinteren Stromgebiet                                   Roman
#
#       volumeInfo.authors  volumeInfo.publisher volumeInfo.publishedDate  \
# 380  [Joachim Meyerhoff]  Kiepenheuer & Witsch               2020-09-10
# 381  [Joachim Meyerhoff]                   NaN               2022-10-06
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 380  Was passiert, wenn man durch einen gesundheitl...                 294.0
# 381                                                NaN                 464.0
#
#     volumeInfo.categories               volumeInfo.imageLinks.smallThumbnail  \
# 380             [Fiction]  http://books.google.com/books/content?id=cB_iD...
# 381                   NaN                                                NaN
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 380  http://books.google.com/books/content?id=cB_iD...               DE
# 381                                                NaN               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 380                         9.99                               EUR
# 381                          NaN                               NaN
#                                               selfLink volumeInfo.title  \
# 22   https://www.googleapis.com/books/v1/volumes/Rs...           Helden
# 390  https://www.googleapis.com/books/v1/volumes/Rs...           Helden
# 391  https://www.googleapis.com/books/v1/volumes/l6...           Helden
# 392  https://www.googleapis.com/books/v1/volumes/wx...           Helden
#
#                               volumeInfo.subtitle volumeInfo.authors  \
# 22   Die klassischen Sagen der Antike neu erzählt      [Stephen Fry]
# 390  Die klassischen Sagen der Antike neu erzählt      [Stephen Fry]
# 391  Die klassischen Sagen der Antike neu erzählt      [Stephen Fry]
# ...
# 602                                                NaN                   0.0
#
#     volumeInfo.categories               volumeInfo.imageLinks.smallThumbnail  \
# 323                   NaN  http://books.google.com/books/content?id=if1i5...
# 600                   NaN  http://books.google.com/books/content?id=if1i5...
# 601             [Fiction]  http://books.google.com/books/content?id=eBC7D...
# 602                   NaN                                                NaN
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 323  http://books.google.com/books/content?id=if1i5...               DE
# 600  http://books.google.com/books/content?id=if1i5...               DE
# 601  http://books.google.com/books/content?id=eBC7D...               DE
# 602                                                NaN               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 323                          NaN                               NaN
# 600                          NaN                               NaN
# 601                        14.99                               EUR
# 602                          NaN                               NaN
# Empty DataFrame
# Columns: [selfLink, volumeInfo.title, volumeInfo.subtitle, volumeInfo.authors, volumeInfo.publisher, volumeInfo.publishedDate, volumeInfo.description, volumeInfo.pageCount, volumeInfo.categories, volumeInfo.imageLinks.smallThumbnail, volumeInfo.imageLinks.thumbnail, saleInfo.country, saleInfo.retailPrice.amount, saleInfo.retailPrice.currencyCode]
# Index: []
# Not match found for Campbell Biologie
#                                               selfLink volumeInfo.title  \
# 621  https://www.googleapis.com/books/v1/volumes/co...    Bullshit Jobs
# 622  https://www.googleapis.com/books/v1/volumes/B3...    Bullshit Jobs
#
#             volumeInfo.subtitle volumeInfo.authors volumeInfo.publisher  \
# 621                    A Theory    [David Graeber]     Simon & Schuster
# 622  Vom wahren Sinn der Arbeit    [David Graeber]          Klett-Cotta
#
#     volumeInfo.publishedDate  \
# 621               2019-05-07
# 622               2018-08-28
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 621  From bestselling writer David Graeber—“a maste...                 368.0
# 622  Im Jahr 1930 prophezeite der britische Ökonom ...                 381.0
#
#       volumeInfo.categories  \
# 621  [Business & Economics]
# 622     [Political Science]
#
#                   volumeInfo.imageLinks.smallThumbnail  \
# 621  http://books.google.com/books/content?id=co2RD...
# 622  http://books.google.com/books/content?id=B3VZD...
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 621  http://books.google.com/books/content?id=co2RD...               DE
# 622  http://books.google.com/books/content?id=B3VZD...               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 621                          NaN                               NaN
# 622                         9.99                               EUR
#                                               selfLink     volumeInfo.title  \
# 630  https://www.googleapis.com/books/v1/volumes/1E...  Das Café ohne Namen
# 631  https://www.googleapis.com/books/v1/volumes/m3...  Das Café ohne Namen
# 632  https://www.googleapis.com/books/v1/volumes/gp...  Das Café ohne Namen
#
#                                    volumeInfo.subtitle  volumeInfo.authors  \
# 630  Roman | Der neue Roman des Bestsellerautors vo...  [Robert Seethaler]
# 631                                              Roman  [Robert Seethaler]
# 632                                              5 CDs  [Robert Seethaler]
#
#      volumeInfo.publisher volumeInfo.publishedDate  \
# 630  Ullstein Buchverlage               2023-04-26
# 631                   NaN                     2023
# 632                   NaN                     2023
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 630  Ein Café und seine Menschen. Ein Mann, der sei...                 212.0
# 631                                                NaN                   0.0
# 632                                                NaN                   0.0
#
#     volumeInfo.categories               volumeInfo.imageLinks.smallThumbnail  \
# 630             [Fiction]  http://books.google.com/books/content?id=1E-WE...
# 631                   NaN                                                NaN
# 632             [Fiction]                                                NaN
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 630  http://books.google.com/books/content?id=1E-WE...               DE
# 631                                                NaN               DE
# 632                                                NaN               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 630                        19.99                               EUR
# 631                          NaN                               NaN
# 632                          NaN                               NaN
#                                               selfLink   volumeInfo.title  \
# 641  https://www.googleapis.com/books/v1/volumes/vo...  Beren and Lúthien
# 642  https://www.googleapis.com/books/v1/volumes/gm...  Beren and Lúthien
#
#     volumeInfo.subtitle  volumeInfo.authors volumeInfo.publisher  \
# 641                 NaN  [J. R. R. Tolkien]        HarperCollins
# 642                 NaN  [J. R. R. Tolkien]        HarperCollins
#
#     volumeInfo.publishedDate  \
# 641               2017-05-04
# 642               2017-06-01
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 641  Painstakingly restored from Tolkien's manuscri...                 304.0
# 642  Painstakingly restored from Tolkien’s manuscri...                 244.0
#
#     volumeInfo.categories               volumeInfo.imageLinks.smallThumbnail  \
# 641                   NaN  http://books.google.com/books/content?id=vox-v...
# 642             [Fiction]  http://books.google.com/books/content?id=gmlID...
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 641  http://books.google.com/books/content?id=vox-v...               DE
# 642  http://books.google.com/books/content?id=gmlID...               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 641                          NaN                               NaN
# 642                         6.99                               EUR
#                                               selfLink volumeInfo.title  \
# 213  https://www.googleapis.com/books/v1/volumes/bV...         BECOMING
# 650  https://www.googleapis.com/books/v1/volumes/bV...         BECOMING
#
#     volumeInfo.subtitle volumeInfo.authors volumeInfo.publisher  \
# 213    Meine Geschichte   [Michelle Obama]      Goldmann Verlag
# 650    Meine Geschichte   [Michelle Obama]      Goldmann Verlag
#
#     volumeInfo.publishedDate  \
# 213               2018-11-13
# 650               2018-11-13
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 213  Die kraftvolle und inspirierende Autobiografie...                 560.0
# 650  Die kraftvolle und inspirierende Autobiografie...                 560.0
#
#            volumeInfo.categories  \
# 213  [Biography & Autobiography]
# 650  [Biography & Autobiography]
#
#                   volumeInfo.imageLinks.smallThumbnail  \
# 213  http://books.google.com/books/content?id=bV9OD...
# 650  http://books.google.com/books/content?id=bV9OD...
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 213  http://books.google.com/books/content?id=bV9OD...               DE
# 650  http://books.google.com/books/content?id=bV9OD...               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 213                        12.99                               EUR
# 650                        12.99                               EUR
#                                               selfLink volumeInfo.title  \
# 663  https://www.googleapis.com/books/v1/volumes/fF...    Atomic Habits
#
#                               volumeInfo.subtitle volumeInfo.authors  \
# 663  the life-changing million-copy #1 bestseller      [James Clear]
#
#     volumeInfo.publisher volumeInfo.publishedDate  \
# 663         Random House               2018-10-18
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 663  THE PHENOMENAL INTERNATIONAL BESTSELLER: OVER ...                 234.0
#
#     volumeInfo.categories               volumeInfo.imageLinks.smallThumbnail  \
# 663           [Self-Help]  http://books.google.com/books/content?id=fFCjD...
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 663  http://books.google.com/books/content?id=fFCjD...               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 663                        14.99                               EUR
#                                               selfLink volumeInfo.title  \
# 670  https://www.googleapis.com/books/v1/volumes/im...       Astronomie
#
#            volumeInfo.subtitle    volumeInfo.authors  \
# 670  die kosmische Perspektive  [Jeffrey O. Bennett]
#
#          volumeInfo.publisher volumeInfo.publishedDate volumeInfo.description  \
# 670  Pearson Deutschland GmbH                     2010                    NaN
#
#      volumeInfo.pageCount volumeInfo.categories  \
# 670                1228.0           [Astronomy]
#
#                   volumeInfo.imageLinks.smallThumbnail  \
# 670  http://books.google.com/books/content?id=im_SY...
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 670  http://books.google.com/books/content?id=im_SY...               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 670                          NaN                               NaN
#                                               selfLink volumeInfo.title  \
# 313  https://www.googleapis.com/books/v1/volumes/Mg...              Ali
# 314  https://www.googleapis.com/books/v1/volumes/WR...              Ali
# 680  https://www.googleapis.com/books/v1/volumes/WR...              Ali
# 681  https://www.googleapis.com/books/v1/volumes/Mg...              Ali
#
#     volumeInfo.subtitle volumeInfo.authors       volumeInfo.publisher  \
# 313              A Life     [Jonathan Eig]  Houghton Mifflin Harcourt
# 314           Ein Leben     [Jonathan Eig]                        DVA
# 680           Ein Leben     [Jonathan Eig]                        DVA
# 681              A Life     [Jonathan Eig]  Houghton Mifflin Harcourt
#
#     volumeInfo.publishedDate  \
# 313                     2017
# 314               2018-05-29
# 680               2018-05-29
# 681                     2017
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 313  Based on more than 500 interviews, including M...                 661.0
# 314  Das schillernde Leben der Boxlegende ganz neu ...                 750.0
# 680  Das schillernde Leben der Boxlegende ganz neu ...                 750.0
# 681  Based on more than 500 interviews, including M...                 661.0
#
#            volumeInfo.categories  \
# 313  [BIOGRAPHY & AUTOBIOGRAPHY]
# 314  [Biography & Autobiography]
# 680  [Biography & Autobiography]
# 681  [BIOGRAPHY & AUTOBIOGRAPHY]
#
#                   volumeInfo.imageLinks.smallThumbnail  \
# 313  http://books.google.com/books/content?id=MgNLD...
# 314  http://books.google.com/books/content?id=WRw-D...
# 680  http://books.google.com/books/content?id=WRw-D...
# 681  http://books.google.com/books/content?id=MgNLD...
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 313  http://books.google.com/books/content?id=MgNLD...               DE
# 314  http://books.google.com/books/content?id=WRw-D...               DE
# 680  http://books.google.com/books/content?id=WRw-D...               DE
# 681  http://books.google.com/books/content?id=MgNLD...               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 313                          NaN                               NaN
# 314                        29.99                               EUR
# 680                        29.99                               EUR
# 681                          NaN                               NaN
#                                               selfLink volumeInfo.title  \
# 690  https://www.googleapis.com/books/v1/volumes/kT...      Anaximander
#
#            volumeInfo.subtitle volumeInfo.authors volumeInfo.publisher  \
# 690  And the Nature of Science    [Carlo Rovelli]         Random House
#
#     volumeInfo.publishedDate  \
# 690               2023-02-23
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 690  'Anaximander is a delight and so is this book'...                 195.0
#
#     volumeInfo.categories               volumeInfo.imageLinks.smallThumbnail  \
# 690             [Science]  http://books.google.com/books/content?id=kTpwE...
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 690  http://books.google.com/books/content?id=kTpwE...               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 690                        14.99                               EUR
# Empty DataFrame
# Columns: [selfLink, volumeInfo.title, volumeInfo.subtitle, volumeInfo.authors, volumeInfo.publisher, volumeInfo.publishedDate, volumeInfo.description, volumeInfo.pageCount, volumeInfo.categories, volumeInfo.imageLinks.smallThumbnail, volumeInfo.imageLinks.thumbnail, saleInfo.country, saleInfo.retailPrice.amount, saleInfo.retailPrice.currencyCode]
# Index: []
# Not match found for Annette, ein Heldinnenepos
#                                               selfLink volumeInfo.title  \
# 710  https://www.googleapis.com/books/v1/volumes/dN...        22 Bahnen
# 712  https://www.googleapis.com/books/v1/volumes/x6...        22 Bahnen
# 715  https://www.googleapis.com/books/v1/volumes/On...        22 Bahnen
#
#                                    volumeInfo.subtitle volumeInfo.authors  \
# 710  Roman | Lieblingsbuch des unabhängigen Buchhan...    [Caroline Wahl]
# 712  Roman | »Ich bin durch ¿22 Bahnen¿ gerauscht u...    [Caroline Wahl]
# 715                                            Lektüre    [Caroline Wahl]
#
#     volumeInfo.publisher volumeInfo.publishedDate  \
# 710    Dumont Buchverlag               2023-04-18
# 712                  NaN               2024-04-16
# 715                  NaN                  2024-10
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 710  Tildas Tage sind strikt durchgetaktet: studier...                 185.0
# 712                                                NaN                   0.0
# 715                                                NaN                   0.0
#
#     volumeInfo.categories               volumeInfo.imageLinks.smallThumbnail  \
# 710             [Fiction]  http://books.google.com/books/content?id=dN2aE...
# 712             [Fiction]                                                NaN
# 715                   NaN                                                NaN
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 710  http://books.google.com/books/content?id=dN2aE...               DE
# 712                                                NaN               DE
# 715                                                NaN               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 710                        10.99                               EUR
# 712                          NaN                               NaN
# 715                          NaN                               NaN

# %%
clean_google_data
# Out:
#                                               selfLink  \
# 30   https://www.googleapis.com/books/v1/volumes/nG...
# 40   https://www.googleapis.com/books/v1/volumes/mk...
# 68   https://www.googleapis.com/books/v1/volumes/nc...
# 71   https://www.googleapis.com/books/v1/volumes/vR...
# 82   https://www.googleapis.com/books/v1/volumes/GU...
# 102  https://www.googleapis.com/books/v1/volumes/el...
# 110  https://www.googleapis.com/books/v1/volumes/gW...
# 121  https://www.googleapis.com/books/v1/volumes/a_...
# 130  https://www.googleapis.com/books/v1/volumes/g9...
# 150  https://www.googleapis.com/books/v1/volumes/p3...
# 160  https://www.googleapis.com/books/v1/volumes/T7...
# 180  https://www.googleapis.com/books/v1/volumes/U7...
# 193  https://www.googleapis.com/books/v1/volumes/ZK...
# 202  https://www.googleapis.com/books/v1/volumes/je...
# 221  https://www.googleapis.com/books/v1/volumes/wM...
# 230  https://www.googleapis.com/books/v1/volumes/IP...
# 240  https://www.googleapis.com/books/v1/volumes/W9...
# 259  https://www.googleapis.com/books/v1/volumes/FK...
# 260  https://www.googleapis.com/books/v1/volumes/tI...
# 276  https://www.googleapis.com/books/v1/volumes/2C...
# 283  https://www.googleapis.com/books/v1/volumes/9A...
# 291  https://www.googleapis.com/books/v1/volumes/Iy...
# 300  https://www.googleapis.com/books/v1/volumes/VZ...
# 310  https://www.googleapis.com/books/v1/volumes/3Z...
# 320  https://www.googleapis.com/books/v1/volumes/px...
# 331  https://www.googleapis.com/books/v1/volumes/R7...
# 350  https://www.googleapis.com/books/v1/volumes/6Z...
# 370  https://www.googleapis.com/books/v1/volumes/sF...
# 381  https://www.googleapis.com/books/v1/volumes/FE...
# 391  https://www.googleapis.com/books/v1/volumes/l6...
# 400  https://www.googleapis.com/books/v1/volumes/-5...
# 418  https://www.googleapis.com/books/v1/volumes/2X...
# 440  https://www.googleapis.com/books/v1/volumes/Dt...
# 450  https://www.googleapis.com/books/v1/volumes/UD...
# 456  https://www.googleapis.com/books/v1/volumes/n9...
# 480  https://www.googleapis.com/books/v1/volumes/GF...
# 500  https://www.googleapis.com/books/v1/volumes/RE...
# 520  https://www.googleapis.com/books/v1/volumes/1G...
# 531  https://www.googleapis.com/books/v1/volumes/CQ...
# 540  https://www.googleapis.com/books/v1/volumes/UB...
# 560  https://www.googleapis.com/books/v1/volumes/wy...
# 571  https://www.googleapis.com/books/v1/volumes/Eo...
# 580  https://www.googleapis.com/books/v1/volumes/Oc...
# 590  https://www.googleapis.com/books/v1/volumes/Kp...
# 602  https://www.googleapis.com/books/v1/volumes/oY...
# 621  https://www.googleapis.com/books/v1/volumes/co...
# 630  https://www.googleapis.com/books/v1/volumes/1E...
# 642  https://www.googleapis.com/books/v1/volumes/gm...
# 213  https://www.googleapis.com/books/v1/volumes/bV...
# 663  https://www.googleapis.com/books/v1/volumes/fF...
# 670  https://www.googleapis.com/books/v1/volumes/im...
# 314  https://www.googleapis.com/books/v1/volumes/WR...
# 690  https://www.googleapis.com/books/v1/volumes/kT...
# 715  https://www.googleapis.com/books/v1/volumes/On...
#
#                         volumeInfo.title  \
# 30                         Über Menschen
# 40                               Zur See
# 68                 To Kill a Mockingbird
# 71                        The Innovators
# 82                      The Code Breaker
# 102                The Children of Hurin
# 110                        Sei du selbst
# 121                          Prima facie
# 130                                 SPQR
# 150                           Offene See
# 160                           Noch wach?
# 180           Nachrichten aus Mittelerde
# 193              Napoleon und seine Zeit
# 202                          Montecristo
# 221                              Mutabor
# 230                             Monschau
# 240                          MONEYMAKERS
# 259                        Madame Bovary
# 260                           Lichtspiel
# 276                               MANIAC
# 283                    Leonardo da Vinci
# 291                    Krieg und Frieden
# 300                  Klara und die Sonne
# 310                         King: A Life
# 320                        Ich bin Circe
# 331                            Humankind
# 350      How to Avoid a Climate Disaster
# 370                                Homer
# 381      Hamster im hinteren Stromgebiet
# 391                               Helden
# 400         Hast du uns endlich gefunden
# 418                               Hamlet
# 440                 Ein verheißenes Land
# 450                            Elon Musk
# 456                             Einstein
# 480                     Diese Wahrheiten
# 500                     Die Verteidigung
# 520                Der heilige King Kong
# 531  Die 13 1/2 Leben des Käpt'n Blaubär
# 540                           Der Fetzen
# 560                     Das blinde Licht
# 571          Das Zeitalter der Unschärfe
# 580      Das Universum in der Nussschale
# 590                     Das Silmarillion
# 602                  Das Lied des Achill
# 621                        Bullshit Jobs
# 630                  Das Café ohne Namen
# 642                    Beren and Lúthien
# 213                             BECOMING
# 663                        Atomic Habits
# 670                           Astronomie
# 314                                  Ali
# 690                          Anaximander
# 715                            22 Bahnen
#
#                                    volumeInfo.subtitle  \
# 30                                               Roman
# 40                     Roman - Der Nummer 1 Bestseller
# 68                                                 NaN
# 71   Die Vordenker der digitalen Revolution von Ada...
# 82   Jennifer Doudna, Gene Editing, and the Future ...
# 102                                                NaN
# 110                       Geschichte der Philosophie 3
# 121                                            A novel
# 130                 Die tausendjährige Geschichte Roms
# 150                                              Roman
# 160                                              Roman
# 180                                                NaN
# 193                                          1769-1821
# 202                                                NaN
# 221                                              Roman
# 230                                                NaN
# 240         Wie du die Börse für dich entdecken kannst
# 259                                                NaN
# 260  Roman | "Ein Geniestreich von einem Roman, ein...
# 276                                              Roman
# 283                                     Die Biographie
# 291                                                NaN
# 300                                              Roman
# 310                                                NaN
# 320  Roman | Eine rebellische Neuerzählung des Myth...
# 331                                  A Hopeful History
# 350  The Solutions We Have and the Breakthroughs We...
# 370                                    eine Einführung
# 381                                              Roman
# 391       Die klassischen Sagen der Antike neu erzählt
# 400                                                NaN
# 418                             Leinen mit Goldprägung
# 440                                                NaN
# 450                                                NaN
# 456  Die Biografie - Der New York Times-Bestseller ...
# 480  Eine Geschichte der Vereinigten Staaten von Am...
# 500                                              Roman
# 520                                              Roman
# 531                                            Roman -
# 540                                                NaN
# 560                        Irrfahrten der Wissenschaft
# 571                                                NaN
# 580                                                NaN
# 590                                                NaN
# 602  Deluxe-Ausgabe mit Goldschnitt. Der Mythos Ach...
# 621                                           A Theory
# 630  Roman | Der neue Roman des Bestsellerautors vo...
# 642                                                NaN
# 213                                   Meine Geschichte
# 663       the life-changing million-copy #1 bestseller
# 670                          die kosmische Perspektive
# 314                                          Ein Leben
# 690                          And the Nature of Science
# 715                                            Lektüre
#
#                            volumeInfo.authors  \
# 30                                 [Juli Zeh]
# 40                             [Dörte Hansen]
# 68                               [Harper Lee]
# 71                          [Walter Isaacson]
# 82                          [Walter Isaacson]
# 102                        [J. R. R. Tolkien]
# 110                    [Richard David Precht]
# 121                            [Suzie Miller]
# 130                              [Mary Beard]
# 150                          [Benjamin Myers]
# 160             [Benjamin von Stuckrad-Barre]
# 180                          [J.R.R. Tolkien]
# 193                                       NaN
# 202                            [Martin Suter]
# 221                         [Norbert Scheuer]
# 230                        [Steffen Kopetzky]
# 240                                [Aya Jaff]
# 259  [Gustave Flaubert, Eleanor Marx Aveling]
# 260                         [Daniel Kehlmann]
# 276                        [Benjamín Labatut]
# 283                         [Walter Isaacson]
# 291                             [Leo Tolstoi]
# 300                          [Kazuo Ishiguro]
# 310                            [Jonathan Eig]
# 320                         [Madeline Miller]
# 331                          [Rutger Bregman]
# 350                              [Bill Gates]
# 370                      [Gustav Adolf Seeck]
# 381                       [Joachim Meyerhoff]
# 391                             [Stephen Fry]
# 400                             [Edgar Selge]
# 418                     [William Shakespeare]
# 440                            [Barack Obama]
# 450                         [Walter Isaacson]
# 456                         [Walter Isaacson]
# 480                             [Jill Lepore]
# 500                         [Fridolin Schley]
# 520                           [James McBride]
# 531                            [Walter Moers]
# 540                         [Philippe Lançon]
# 560                        [Benjamín Labatut]
# 571                           [Tobias Hürter]
# 580                      [Stephen W. Hawking]
# 590                          [J.R.R. Tolkien]
# 602                         [Madeline Miller]
# 621                           [David Graeber]
# 630                        [Robert Seethaler]
# 642                        [J. R. R. Tolkien]
# 213                          [Michelle Obama]
# 663                             [James Clear]
# 670                      [Jeffrey O. Bennett]
# 314                            [Jonathan Eig]
# 690                           [Carlo Rovelli]
# 715                           [Caroline Wahl]
#
#                  volumeInfo.publisher volumeInfo.publishedDate  \
# 30        Luchterhand Literaturverlag               2021-03-22
# 40    Verlagsgruppe Random House GmbH               2022-09-28
# 68   Harper Perennial Modern Classics               2006-05-23
# 71              C. Bertelsmann Verlag               2018-04-23
# 82                 Simon and Schuster               2022-05-03
# 102                     Mariner Books                  2008-10
# 110                   Goldmann Verlag               2019-10-14
# 121    Carl Hanser Verlag GmbH  Co KG               2024-01-29
# 130                 S. Fischer Verlag               2016-10-13
# 150                 Dumont Buchverlag               2020-03-20
# 160              Kiepenheuer & Witsch               2023-04-22
# 180                       Klett Cotta               2012-03-15
# 193                               NaN                     2012
# 202         Bedford Square Publishers               2016-06-22
# 221                               NaN               2022-08-25
# 230               Rowohlt Verlag GmbH               2021-03-23
# 240                 FinanzBuch Verlag               2020-05-09
# 259  E-Kitap Projesi & Cheapest Books               2024-01-23
# 260               Rowohlt Verlag GmbH               2023-10-10
# 276                               NaN                     2024
# 283                               NaN               2019-11-29
# 291                Null Papier Verlag               2019-05-27
# 300              Karl Blessing Verlag               2021-03-15
# 310         Farrar, Straus and Giroux               2023-05-16
# 320              Ullstein Buchverlage               2019-08-30
# 331             Bloomsbury Publishing               2020-05-19
# 350                        Penguin UK               2021-02-16
# 370                               NaN                     2004
# 381                               NaN               2022-10-06
# 391                               NaN               2022-09-20
# 400               Rowohlt Verlag GmbH               2021-10-19
# 418                               NaN               2020-09-10
# 440                    Penguin Verlag               2020-11-17
# 450                            Fayard               2023-09-13
# 456             C. Bertelsmann Verlag               2024-10-30
# 480                          C.H.Beck               2019-10-15
# 500                     Hanser Berlin               2021-08-23
# 520                        btb Verlag               2021-03-15
# 531   Verlagsgruppe Random House GmbH               2019-09-09
# 540                               NaN               2019-03-23
# 560                               NaN               2021-07-18
# 571                               NaN               2023-05-20
# 580                               NaN                  2004-01
# 590                       Klett-Cotta               2010-08-25
# 602                               NaN                     2024
# 621                  Simon & Schuster               2019-05-07
# 630              Ullstein Buchverlage               2023-04-26
# 642                     HarperCollins               2017-06-01
# 213                   Goldmann Verlag               2018-11-13
# 663                      Random House               2018-10-18
# 670          Pearson Deutschland GmbH                     2010
# 314                               DVA               2018-05-29
# 690                      Random House               2023-02-23
# 715                               NaN                  2024-10
#
#                                 volumeInfo.description  volumeInfo.pageCount  \
# 30   Dora ist mit ihrer kleinen Hündin aufs Land ge...                 351.0
# 40   Der dritte Roman von Bestsellerautorin Dörte H...                 193.0
# 68   Harper Lee's Pulitzer Prize-winning masterwork...                 346.0
# 71   Sind sie jetzt Nerds, Weltverbesserer oder Spi...                 479.0
# 82   "A gripping account of how the pioneering scie...                 560.0
# 102  A fantasy adventure saga set in the early days...                 313.0
# 110  Der lang erwartete dritte Band von Prechts fün...                 503.0
# 121  Das Gesetz ist dazu da, ALLE Menschen zu besch...                 320.0
# 130  Die Geschichte Roms für unsere Zeit: Wer hätte...                 774.0
# 150  Eine zeitlose und geradezu zärtliche Geschicht...                 234.0
# 160  Berlin: Eine junge Frau erzählt von ihrem neue...                 365.0
# 180  Verstreute Nachrichten, vergessen geglaubte Ge...                 630.0
# 193                                                NaN                   0.0
# 202  Video journalist Jonas Brand is on a rail jour...                 283.0
# 221                                                NaN                 176.0
# 230  Im Jahr 1962, als das nukleare Wettrüsten sein...                 230.0
# 240  MONEY MAKERS zeigt dir, wie du den Schritt an ...                 197.0
# 259  Madame Bovary takes place in provincial northe...                 499.0
# 260  Einer der Größten des Kinos, vielleicht der gr...                 440.0
# 276                                                NaN                   0.0
# 283                                                NaN                 752.0
# 291  Zwischen 1863 und 1869 schuf Leo Tolstoi diese...                1785.0
# 300  Der neue Roman des Nobelpreisträgers Klara ist...                 265.0
# 310  WINNER OF THE 2024 PULITZER PRIZE FOR BIOGRAPH...                 453.0
# 320  Unsterblich. Unvollkommen. Unbezähmbar. Circe ...                 493.0
# 331  THE SUNDAY TIMES AND NEW YORK TIMES BESTSELLER...                 496.0
# 350  In this urgent, authoritative book, Bill Gates...                 175.0
# 370                                                NaN                 300.0
# 381                                                NaN                 464.0
# 391                                                NaN                 461.0
# 400  Das literarische Debüt von Edgar Selge: Ein Zw...                 326.0
# 418                                                NaN                 176.0
# 440  Ein fesselnder und zutiefst persönlicher Beric...                 681.0
# 450  Écrit par l’auteur de la biographie autorisée ...                 918.0
# 456  Die Bestsellerbiografie über Albert Einstein —...                   0.0
# 480  WELTMACHT AM SCHEIDEWEG - JILL LEPORES BRILLAN...                1363.0
# 500  1947, die Nürnberger Prozesse: Einer der Angek...                 244.0
# 520  Barack Obama - Lieblingsbücher 2020 Die ruhige...                 448.0
# 531  »Das Leben ist zu kostbar, um es dem Schicksal...                 635.0
# 540                                                NaN                 512.0
# 560                                                NaN                 187.0
# 571                                                NaN                   0.0
# 580                                                NaN                 262.0
# 590  Das Silmarillion erzählt die Götter- und Helde...                 566.0
# 602                                                NaN                   0.0
# 621  From bestselling writer David Graeber—“a maste...                 368.0
# 630  Ein Café und seine Menschen. Ein Mann, der sei...                 212.0
# 642  Painstakingly restored from Tolkien’s manuscri...                 244.0
# 213  Die kraftvolle und inspirierende Autobiografie...                 560.0
# 663  THE PHENOMENAL INTERNATIONAL BESTSELLER: OVER ...                 234.0
# 670                                                NaN                1228.0
# 314  Das schillernde Leben der Boxlegende ganz neu ...                 750.0
# 690  'Anaximander is a delight and so is this book'...                 195.0
# 715                                                NaN                   0.0
#
#            volumeInfo.categories  \
# 30                     [Fiction]
# 40                     [Fiction]
# 68                     [Fiction]
# 71   [Biography & Autobiography]
# 82   [Biography & Autobiography]
# 102                    [Fiction]
# 110                 [Philosophy]
# 121                    [Fiction]
# 130                    [History]
# 150                    [Fiction]
# 160                    [Fiction]
# 180                    [Fiction]
# 193                          NaN
# 202                    [Fiction]
# 221                          NaN
# 230                    [Fiction]
# 240       [Business & Economics]
# 259                    [Fiction]
# 260                    [Fiction]
# 276                          NaN
# 283  [Biography & Autobiography]
# 291                    [Fiction]
# 300                    [Fiction]
# 310  [Biography & Autobiography]
# 320                    [Fiction]
# 331       [Business & Economics]
# 350                    [Science]
# 370         [Epic poetry, Greek]
# 381                          NaN
# 391                          NaN
# 400                    [Fiction]
# 418                          NaN
# 440  [Biography & Autobiography]
# 450             [Social Science]
# 456  [Biography & Autobiography]
# 480                    [History]
# 500                    [Fiction]
# 520                    [Fiction]
# 531                    [Fiction]
# 540                          NaN
# 560                          NaN
# 571                          NaN
# 580                          NaN
# 590                    [Fiction]
# 602                          NaN
# 621       [Business & Economics]
# 630                    [Fiction]
# 642                    [Fiction]
# 213  [Biography & Autobiography]
# 663                  [Self-Help]
# 670                  [Astronomy]
# 314  [Biography & Autobiography]
# 690                    [Science]
# 715                          NaN
#
#                   volumeInfo.imageLinks.smallThumbnail  \
# 30   http://books.google.com/books/content?id=nGIGE...
# 40   http://books.google.com/books/content?id=mkVnE...
# 68   http://books.google.com/books/content?id=ncuX8...
# 71   http://books.google.com/books/content?id=vRs-D...
# 82   http://books.google.com/books/content?id=GUSFE...
# 102  http://books.google.com/books/content?id=eldcP...
# 110  http://books.google.com/books/content?id=gWaiC...
# 121  http://books.google.com/books/content?id=a_LnE...
# 130  http://books.google.com/books/content?id=g9ARD...
# 150  http://books.google.com/books/content?id=p3nAD...
# 160  http://books.google.com/books/content?id=T7y6E...
# 180  http://books.google.com/books/content?id=U7W5w...
# 193                                                NaN
# 202  http://books.google.com/books/content?id=jerVE...
# 221                                                NaN
# 230  http://books.google.com/books/content?id=IPQIE...
# 240  http://books.google.com/books/content?id=W9DID...
# 259  http://books.google.com/books/content?id=FKHuE...
# 260  http://books.google.com/books/content?id=tIm2E...
# 276                                                NaN
# 283                                                NaN
# 291  http://books.google.com/books/content?id=Iyq6D...
# 300  http://books.google.com/books/content?id=VZTwD...
# 310  http://books.google.com/books/content?id=3ZyDE...
# 320  http://books.google.com/books/content?id=pxKTD...
# 331  http://books.google.com/books/content?id=R7rED...
# 350  http://books.google.com/books/content?id=6Z6zD...
# 370  http://books.google.com/books/content?id=sFpiA...
# 381                                                NaN
# 391                                                NaN
# 400  http://books.google.com/books/content?id=-5grE...
# 418                                                NaN
# 440  http://books.google.com/books/content?id=DtD9D...
# 450  http://books.google.com/books/content?id=UD3HE...
# 456  http://books.google.com/books/content?id=n9_-E...
# 480  http://books.google.com/books/content?id=GFqvD...
# 500  http://books.google.com/books/content?id=REgpE...
# 520  http://books.google.com/books/content?id=1GAGE...
# 531  http://books.google.com/books/content?id=CQGSD...
# 540                                                NaN
# 560                                                NaN
# 571                                                NaN
# 580  http://books.google.com/books/content?id=OcvWP...
# 590  http://books.google.com/books/content?id=KpLpy...
# 602                                                NaN
# 621  http://books.google.com/books/content?id=co2RD...
# 630  http://books.google.com/books/content?id=1E-WE...
# 642  http://books.google.com/books/content?id=gmlID...
# 213  http://books.google.com/books/content?id=bV9OD...
# 663  http://books.google.com/books/content?id=fFCjD...
# 670  http://books.google.com/books/content?id=im_SY...
# 314  http://books.google.com/books/content?id=WRw-D...
# 690  http://books.google.com/books/content?id=kTpwE...
# 715                                                NaN
#
#                        volumeInfo.imageLinks.thumbnail saleInfo.country  \
# 30   http://books.google.com/books/content?id=nGIGE...               DE
# 40   http://books.google.com/books/content?id=mkVnE...               DE
# 68   http://books.google.com/books/content?id=ncuX8...               DE
# 71   http://books.google.com/books/content?id=vRs-D...               DE
# 82   http://books.google.com/books/content?id=GUSFE...               DE
# 102  http://books.google.com/books/content?id=eldcP...               DE
# 110  http://books.google.com/books/content?id=gWaiC...               DE
# 121  http://books.google.com/books/content?id=a_LnE...               DE
# 130  http://books.google.com/books/content?id=g9ARD...               DE
# 150  http://books.google.com/books/content?id=p3nAD...               DE
# 160  http://books.google.com/books/content?id=T7y6E...               DE
# 180  http://books.google.com/books/content?id=U7W5w...               DE
# 193                                                NaN               DE
# 202  http://books.google.com/books/content?id=jerVE...               DE
# 221                                                NaN               DE
# 230  http://books.google.com/books/content?id=IPQIE...               DE
# 240  http://books.google.com/books/content?id=W9DID...               DE
# 259  http://books.google.com/books/content?id=FKHuE...               DE
# 260  http://books.google.com/books/content?id=tIm2E...               DE
# 276                                                NaN               DE
# 283                                                NaN               DE
# 291  http://books.google.com/books/content?id=Iyq6D...               DE
# 300  http://books.google.com/books/content?id=VZTwD...               DE
# 310  http://books.google.com/books/content?id=3ZyDE...               DE
# 320  http://books.google.com/books/content?id=pxKTD...               DE
# 331  http://books.google.com/books/content?id=R7rED...               DE
# 350  http://books.google.com/books/content?id=6Z6zD...               DE
# 370  http://books.google.com/books/content?id=sFpiA...               DE
# 381                                                NaN               DE
# 391                                                NaN               DE
# 400  http://books.google.com/books/content?id=-5grE...               DE
# 418                                                NaN               DE
# 440  http://books.google.com/books/content?id=DtD9D...               DE
# 450  http://books.google.com/books/content?id=UD3HE...               DE
# 456  http://books.google.com/books/content?id=n9_-E...               DE
# 480  http://books.google.com/books/content?id=GFqvD...               DE
# 500  http://books.google.com/books/content?id=REgpE...               DE
# 520  http://books.google.com/books/content?id=1GAGE...               DE
# 531  http://books.google.com/books/content?id=CQGSD...               DE
# 540                                                NaN               DE
# 560                                                NaN               DE
# 571                                                NaN               DE
# 580  http://books.google.com/books/content?id=OcvWP...               DE
# 590  http://books.google.com/books/content?id=KpLpy...               DE
# 602                                                NaN               DE
# 621  http://books.google.com/books/content?id=co2RD...               DE
# 630  http://books.google.com/books/content?id=1E-WE...               DE
# 642  http://books.google.com/books/content?id=gmlID...               DE
# 213  http://books.google.com/books/content?id=bV9OD...               DE
# 663  http://books.google.com/books/content?id=fFCjD...               DE
# 670  http://books.google.com/books/content?id=im_SY...               DE
# 314  http://books.google.com/books/content?id=WRw-D...               DE
# 690  http://books.google.com/books/content?id=kTpwE...               DE
# 715                                                NaN               DE
#
#      saleInfo.retailPrice.amount saleInfo.retailPrice.currencyCode
# 30                         10.99                               EUR
# 40                         14.99                               EUR
# 68                           NaN                               NaN
# 71                         19.99                               EUR
# 82                           NaN                               NaN
# 102                          NaN                               NaN
# 110                        19.99                               EUR
# 121                        18.99                               EUR
# 130                         5.99                               EUR
# 150                         9.99                               EUR
# 160                        19.99                               EUR
# 180                        14.99                               EUR
# 193                          NaN                               NaN
# 202                         9.99                               EUR
# 221                          NaN                               NaN
# 230                         9.99                               EUR
# 240                        13.99                               EUR
# 259                         4.99                               EUR
# 260                        22.99                               EUR
# 276                          NaN                               NaN
# 283                          NaN                               NaN
# 291                         0.99                               EUR
# 300                        12.99                               EUR
# 310                        23.95                               EUR
# 320                        14.99                               EUR
# 331                         7.03                               EUR
# 350                         9.49                               EUR
# 370                          NaN                               NaN
# 381                          NaN                               NaN
# 391                          NaN                               NaN
# 400                        11.99                               EUR
# 418                          NaN                               NaN
# 440                        26.99                               EUR
# 450                        18.99                               EUR
# 456                          NaN                               NaN
# 480                        30.99                               EUR
# 500                        11.99                               EUR
# 520                         9.99                               EUR
# 531                        14.99                               EUR
# 540                          NaN                               NaN
# 560                          NaN                               NaN
# 571                          NaN                               NaN
# 580                          NaN                               NaN
# 590                        15.99                               EUR
# 602                          NaN                               NaN
# 621                          NaN                               NaN
# 630                        19.99                               EUR
# 642                         6.99                               EUR
# 213                        12.99                               EUR
# 663                        14.99                               EUR
# 670                          NaN                               NaN
# 314                        29.99                               EUR
# 690                        14.99                               EUR
# 715                          NaN                               NaN

# %% [markdown]
# Continue in debugging mode. Some entries like moby dick seem to be excluded from the matches. Have to find reason why.
